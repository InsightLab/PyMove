# %%
import pandas as pd
import numpy as np
from pymove import MoveDataFrame

# %%
from pymove import compression

# %%
df = pd.read_csv('examples/geolife_sample.csv', parse_dates=['datetime'])
df.head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
df_move = MoveDataFrame(df, latitude="lat", longitude="lon", datetime="datetime")

# %%
#df_move.generate_dist_time_speed_features()

# %%
from pymove import segmentation

# %%
segmentation.segment_traj_by_max_dist(df_move)
# Out:
# Split trajectories by max distance between adjacent points: 3000
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217653/217653) 100% in 00:00:00.092 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.10172367095947266
# ...setting id as index
# C:\Users\Arina\Desktop\PyMove\pymove\preprocessing\segmentation.py:398: RuntimeWarning: invalid value encountered in greater
#   dist = (df_.at[idx, DIST_TO_PREV] > max_dist_between_adj_points)
# (217653/217653) 100% in 00:00:00.032 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.04 seconds
# ------------------------------------------

# %%
from pymove import stay_point_detection

# %%
#stay_point_detection.create_or_update_move_stop_by_dist_time(df_move)

# %%
#df_move

# %%
#df_move['segment_stop'].value_counts()

# %%
#df_move['stop'].value_counts()

# %%
compression.compress_segment_stop_to_point(df_move)
# Out:
# Split trajectories by max distance between adjacent points: 30
# ...setting id as index
# (217653/217653) 100% in 00:00:00.100 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.11 seconds
# ------------------------------------------
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by segment_stop and datetime to increase performance
#
# ...Set segment_stop as index to a higher peformance
#
# (5/217653) 0% in 00:00:00.185 - estimated end in 02:14:34.788
# ...id:5, must have at least 2 GPS points
#
# ...id:10, must have at least 2 GPS points
#
# ...id:11, must have at least 2 GPS points
#
# ...id:12, must have at least 2 GPS points
#
# ...id:14, must have at least 2 GPS points
#
# ...id:35, must have at least 2 GPS points
#
# ...id:52, must have at least 2 GPS points
#
# ...id:71, must have at least 2 GPS points
#
# ...id:72, must have at least 2 GPS points
#
# ...id:84, must have at least 2 GPS points
#
# ...id:86, must have at least 2 GPS points
#
# ...id:87, must have at least 2 GPS points
#
# ...id:91, must have at least 2 GPS points
#
# ...id:92, must have at least 2 GPS points
#
# ...id:99, must have at least 2 GPS points
#
# ...id:103, must have at least 2 GPS points
#
# ...id:104, must have at least 2 GPS points
#
# ...id:107, must have at least 2 GPS points
#
# ...id:112, must have at least 2 GPS points
#
# ...id:120, must have at least 2 GPS points
#
# ...id:135, must have at least 2 GPS points
#
# ...id:139, must have at least 2 GPS points
#
# ...id:143, must have at least 2 GPS points
#
# ...id:164, must have at least 2 GPS points
#
# ...id:166, must have at least 2 GPS points
#
# ...id:175, must have at least 2 GPS points
#
# ...id:182, must have at least 2 GPS points
#
# ...id:185, must have at least 2 GPS points
#
# ...id:188, must have at least 2 GPS points
#
# ...id:189, must have at least 2 GPS points
#
# ...id:190, must have at least 2 GPS points
#
# ...id:193, must have at least 2 GPS points
#
# ...id:201, must have at least 2 GPS points
#
# ...id:203, must have at least 2 GPS points
#
# ...id:206, must have at least 2 GPS points
#
# ...id:207, must have at least 2 GPS points
#
# ...id:208, must have at least 2 GPS points
#
# ...id:213, must have at least 2 GPS points
#
# ...id:222, must have at least 2 GPS points
#
# ...id:225, must have at least 2 GPS points
#
# ...id:227, must have at least 2 GPS points
#
# ...id:232, must have at least 2 GPS points
#
# ...id:233, must have at least 2 GPS points
#
# ...id:236, must have at least 2 GPS points
#
# ...id:240, must have at least 2 GPS points
#
# ...id:242, must have at least 2 GPS points
#
# ...id:246, must have at least 2 GPS points
#
# ...id:248, must have at least 2 GPS points
#
# ...id:252, must have at least 2 GPS points
#
# ...id:255, must have at least 2 GPS points
#
# ...id:259, must have at least 2 GPS points
#
# ...id:262, must have at least 2 GPS points
#
# ...id:274, must have at least 2 GPS points
#
# ...id:286, must have at least 2 GPS points
#
# ...id:295, must have at least 2 GPS points
#
# (43973/217653) 20% in 00:00:00.446 - estimated end in 00:00:01.764
# ...id:301, must have at least 2 GPS points
#
# ...id:305, must have at least 2 GPS points
#
# ...id:310, must have at least 2 GPS points
#
# ...id:311, must have at least 2 GPS points
#
# ...id:318, must have at least 2 GPS points
#
# ...id:321, must have at least 2 GPS points
#
# ...id:322, must have at least 2 GPS points
#
# ...id:327, must have at least 2 GPS points
#
# ...id:329, must have at least 2 GPS points
#
# ...id:340, must have at least 2 GPS points
#
# ...id:343, must have at least 2 GPS points
#
# ...id:345, must have at least 2 GPS points
#
# ...id:349, must have at least 2 GPS points
#
# ...id:350, must have at least 2 GPS points
#
# ...id:352, must have at least 2 GPS points
#
# ...id:360, must have at least 2 GPS points
#
# ...id:367, must have at least 2 GPS points
#
# ...id:372, must have at least 2 GPS points
#
# ...id:373, must have at least 2 GPS points
#
# ...id:376, must have at least 2 GPS points
#
# ...id:385, must have at least 2 GPS points
#
# ...id:394, must have at least 2 GPS points
#
# ...id:398, must have at least 2 GPS points
#
# ...id:399, must have at least 2 GPS points
#
# ...id:400, must have at least 2 GPS points
#
# ...id:404, must have at least 2 GPS points
#
# ...id:405, must have at least 2 GPS points
#
# ...id:408, must have at least 2 GPS points
#
# ...id:413, must have at least 2 GPS points
#
# ...id:420, must have at least 2 GPS points
#
# ...id:430, must have at least 2 GPS points
#
# ...id:431, must have at least 2 GPS points
#
# ...id:433, must have at least 2 GPS points
#
# ...id:435, must have at least 2 GPS points
#
# ...id:438, must have at least 2 GPS points
#
# ...id:440, must have at least 2 GPS points
#
# ...id:445, must have at least 2 GPS points
#
# ...id:457, must have at least 2 GPS points
#
# ...id:471, must have at least 2 GPS points
#
# ...id:495, must have at least 2 GPS points
#
# ...id:499, must have at least 2 GPS points
#
# ...id:510, must have at least 2 GPS points
#
# ...id:513, must have at least 2 GPS points
#
# ...id:516, must have at least 2 GPS points
#
# ...id:523, must have at least 2 GPS points
#
# ...id:525, must have at least 2 GPS points
#
# ...id:528, must have at least 2 GPS points
#
# ...id:532, must have at least 2 GPS points
#
# ...id:533, must have at least 2 GPS points
#
# ...id:537, must have at least 2 GPS points
#
# ...id:544, must have at least 2 GPS points
#
# ...id:545, must have at least 2 GPS points
#
# ...id:553, must have at least 2 GPS points
#
# ...id:558, must have at least 2 GPS points
#
# ...id:561, must have at least 2 GPS points
#
# ...id:569, must have at least 2 GPS points
#
# ...id:571, must have at least 2 GPS points
#
# ...id:575, must have at least 2 GPS points
#
# ...id:577, must have at least 2 GPS points
#
# ...id:584, must have at least 2 GPS points
#
# ...id:585, must have at least 2 GPS points
#
# ...id:588, must have at least 2 GPS points
#
# ...id:598, must have at least 2 GPS points
#
# ...id:602, must have at least 2 GPS points
#
# (88533/217653) 40% in 00:00:00.723 - estimated end in 00:00:01.054
# ...id:614, must have at least 2 GPS points
#
# ...id:616, must have at least 2 GPS points
#
# ...id:619, must have at least 2 GPS points
#
# ...id:621, must have at least 2 GPS points
#
# ...id:627, must have at least 2 GPS points
#
# ...id:632, must have at least 2 GPS points
#
# ...id:634, must have at least 2 GPS points
#
# ...id:637, must have at least 2 GPS points
#
# ...id:641, must have at least 2 GPS points
#
# ...id:642, must have at least 2 GPS points
#
# ...id:655, must have at least 2 GPS points
#
# ...id:660, must have at least 2 GPS points
#
# ...id:661, must have at least 2 GPS points
#
# ...id:666, must have at least 2 GPS points
#
# ...id:667, must have at least 2 GPS points
#
# ...id:669, must have at least 2 GPS points
#
# ...id:671, must have at least 2 GPS points
#
# ...id:672, must have at least 2 GPS points
#
# ...id:674, must have at least 2 GPS points
#
# ...id:692, must have at least 2 GPS points
#
# ...id:696, must have at least 2 GPS points
#
# ...id:699, must have at least 2 GPS points
#
# ...id:712, must have at least 2 GPS points
#
# ...id:719, must have at least 2 GPS points
#
# ...id:720, must have at least 2 GPS points
#
# ...id:721, must have at least 2 GPS points
#
# ...id:722, must have at least 2 GPS points
#
# ...id:724, must have at least 2 GPS points
#
# ...id:725, must have at least 2 GPS points
#
# ...id:726, must have at least 2 GPS points
#
# ...id:727, must have at least 2 GPS points
#
# ...id:728, must have at least 2 GPS points
#
# ...id:729, must have at least 2 GPS points
#
# ...id:730, must have at least 2 GPS points
#
# ...id:731, must have at least 2 GPS points
#
# ...id:733, must have at least 2 GPS points
#
# ...id:736, must have at least 2 GPS points
#
# ...id:737, must have at least 2 GPS points
#
# ...id:744, must have at least 2 GPS points
#
# ...id:746, must have at least 2 GPS points
#
# ...id:747, must have at least 2 GPS points
#
# ...id:750, must have at least 2 GPS points
#
# ...id:751, must have at least 2 GPS points
#
# ...id:753, must have at least 2 GPS points
#
# ...id:757, must have at least 2 GPS points
#
# ...id:760, must have at least 2 GPS points
#
# ...id:762, must have at least 2 GPS points
#
# ...id:766, must have at least 2 GPS points
#
# ...id:771, must have at least 2 GPS points
#
# ...id:772, must have at least 2 GPS points
#
# ...id:773, must have at least 2 GPS points
#
# ...id:775, must have at least 2 GPS points
#
# ...id:776, must have at least 2 GPS points
#
# ...id:777, must have at least 2 GPS points
# ...id:778, must have at least 2 GPS points
#
# ...id:779, must have at least 2 GPS points
#
# ...id:786, must have at least 2 GPS points
#
# ...id:788, must have at least 2 GPS points
#
# ...id:789, must have at least 2 GPS points
#
# ...id:790, must have at least 2 GPS points
#
# ...id:797, must have at least 2 GPS points
#
# ...id:801, must have at least 2 GPS points
#
# ...id:804, must have at least 2 GPS points
#
# ...id:805, must have at least 2 GPS points
#
# ...id:806, must have at least 2 GPS points
#
# ...id:807, must have at least 2 GPS points
#
# ...id:808, must have at least 2 GPS points
#
# ...id:809, must have at least 2 GPS points
#
# ...id:810, must have at least 2 GPS points
#
# ...id:811, must have at least 2 GPS points
#
# ...id:812, must have at least 2 GPS points
#
# ...id:813, must have at least 2 GPS points
#
# ...id:814, must have at least 2 GPS points
#
# ...id:815, must have at least 2 GPS points
#
# ...id:816, must have at least 2 GPS points
#
# ...id:817, must have at least 2 GPS points
#
# ...id:818, must have at least 2 GPS points
#
# ...id:819, must have at least 2 GPS points
#
# ...id:820, must have at least 2 GPS points
#
# ...id:821, must have at least 2 GPS points
#
# ...id:822, must have at least 2 GPS points
#
# ...id:823, must have at least 2 GPS points
#
# ...id:826, must have at least 2 GPS points
#
# ...id:827, must have at least 2 GPS points
#
# ...id:828, must have at least 2 GPS points
#
# ...id:829, must have at least 2 GPS points
#
# ...id:830, must have at least 2 GPS points
#
# ...id:831, must have at least 2 GPS points
#
# ...id:832, must have at least 2 GPS points
#
# ...id:833, must have at least 2 GPS points
#
# ...id:834, must have at least 2 GPS points
#
# ...id:835, must have at least 2 GPS points
#
# ...id:837, must have at least 2 GPS points
#
# ...id:838, must have at least 2 GPS points
#
# ...id:839, must have at least 2 GPS points
#
# ...id:840, must have at least 2 GPS points
#
# ...id:841, must have at least 2 GPS points
#
# ...id:842, must have at least 2 GPS points
#
# ...id:843, must have at least 2 GPS points
#
# ...id:844, must have at least 2 GPS points
#
# ...id:845, must have at least 2 GPS points
#
# ...id:846, must have at least 2 GPS points
#
# ...id:847, must have at least 2 GPS points
#
# ...id:848, must have at least 2 GPS points
#
# ...id:849, must have at least 2 GPS points
#
# ...id:850, must have at least 2 GPS points
#
# ...id:851, must have at least 2 GPS points
#
# ...id:852, must have at least 2 GPS points
#
# ...id:853, must have at least 2 GPS points
#
# ...id:854, must have at least 2 GPS points
#
# ...id:855, must have at least 2 GPS points
#
# ...id:856, must have at least 2 GPS points
#
# ...id:857, must have at least 2 GPS points
#
# ...id:858, must have at least 2 GPS points
#
# ...id:859, must have at least 2 GPS points
#
# ...id:860, must have at least 2 GPS points
#
# ...id:861, must have at least 2 GPS points
#
# ...id:862, must have at least 2 GPS points
#
# ...id:863, must have at least 2 GPS points
#
# ...id:869, must have at least 2 GPS points
#
# ...id:870, must have at least 2 GPS points
#
# ...id:871, must have at least 2 GPS points
#
# ...id:872, must have at least 2 GPS points
#
# ...id:873, must have at least 2 GPS points
#
# ...id:874, must have at least 2 GPS points
#
# ...id:875, must have at least 2 GPS points
#
# ...id:876, must have at least 2 GPS points
#
# ...id:877, must have at least 2 GPS points
#
# ...id:878, must have at least 2 GPS points
#
# ...id:879, must have at least 2 GPS points
#
# ...id:880, must have at least 2 GPS points
#
# ...id:882, must have at least 2 GPS points
#
# ...id:883, must have at least 2 GPS points
#
# ...id:884, must have at least 2 GPS points
#
# ...id:885, must have at least 2 GPS points
#
# ...id:886, must have at least 2 GPS points
#
# ...id:887, must have at least 2 GPS points
#
# ...id:888, must have at least 2 GPS points
#
# ...id:889, must have at least 2 GPS points
#
# ...id:892, must have at least 2 GPS points
#
# ...id:894, must have at least 2 GPS points
#
# ...id:895, must have at least 2 GPS points
#
# ...id:896, must have at least 2 GPS points
#
# ...id:897, must have at least 2 GPS points
#
# ...id:898, must have at least 2 GPS points
#
# ...id:899, must have at least 2 GPS points
#
# ...id:900, must have at least 2 GPS points
#
# ...id:901, must have at least 2 GPS points
#
# ...id:902, must have at least 2 GPS points
#
# ...id:903, must have at least 2 GPS points
#
# ...id:904, must have at least 2 GPS points
#
# ...id:905, must have at least 2 GPS points
#
# ...id:906, must have at least 2 GPS points
#
# ...id:907, must have at least 2 GPS points
#
# ...id:908, must have at least 2 GPS points
#
# ...id:909, must have at least 2 GPS points
#
# ...id:910, must have at least 2 GPS points
#
# ...id:911, must have at least 2 GPS points
#
# ...id:912, must have at least 2 GPS points
#
# ...id:913, must have at least 2 GPS points
#
# ...id:914, must have at least 2 GPS points
#
# ...id:915, must have at least 2 GPS points
#
# ...id:916, must have at least 2 GPS points
#
# ...id:917, must have at least 2 GPS points
#
# ...id:918, must have at least 2 GPS points
#
# ...id:919, must have at least 2 GPS points
#
# ...id:920, must have at least 2 GPS points
#
# ...id:921, must have at least 2 GPS points
#
# ...id:922, must have at least 2 GPS points
#
# ...id:923, must have at least 2 GPS points
#
# ...id:924, must have at least 2 GPS points
#
# ...id:925, must have at least 2 GPS points
#
# ...id:926, must have at least 2 GPS points
#
# ...id:928, must have at least 2 GPS points
#
# ...id:929, must have at least 2 GPS points
#
# ...id:930, must have at least 2 GPS points
#
# ...id:931, must have at least 2 GPS points
#
# ...id:932, must have at least 2 GPS points
#
# ...id:933, must have at least 2 GPS points
#
# ...id:934, must have at least 2 GPS points
#
# ...id:935, must have at least 2 GPS points
#
# ...id:936, must have at least 2 GPS points
#
# ...id:937, must have at least 2 GPS points
#
# ...id:938, must have at least 2 GPS points
#
# ...id:939, must have at least 2 GPS points
#
# ...id:940, must have at least 2 GPS points
#
# ...id:941, must have at least 2 GPS points
#
# ...id:943, must have at least 2 GPS points
#
# ...id:944, must have at least 2 GPS points
#
# ...id:945, must have at least 2 GPS points
#
# ...id:946, must have at least 2 GPS points
#
# ...id:947, must have at least 2 GPS points
#
# ...id:948, must have at least 2 GPS points
#
# ...id:949, must have at least 2 GPS points
#
# ...id:950, must have at least 2 GPS points
#
# ...id:951, must have at least 2 GPS points
#
# ...id:952, must have at least 2 GPS points
#
# ...id:953, must have at least 2 GPS points
#
# ...id:954, must have at least 2 GPS points
#
# ...id:955, must have at least 2 GPS points
#
# ...id:956, must have at least 2 GPS points
#
# ...id:957, must have at least 2 GPS points
#
# ...id:958, must have at least 2 GPS points
#
# ...id:959, must have at least 2 GPS points
#
# ...id:960, must have at least 2 GPS points
#
# ...id:961, must have at least 2 GPS points
#
# ...id:962, must have at least 2 GPS points
#
# ...id:963, must have at least 2 GPS points
#
# ...id:964, must have at least 2 GPS points
#
# ...id:970, must have at least 2 GPS points
#
# ...id:974, must have at least 2 GPS points
#
# ...id:976, must have at least 2 GPS points
#
# ...id:977, must have at least 2 GPS points
#
# ...id:979, must have at least 2 GPS points
#
# ...id:981, must have at least 2 GPS points
#
# ...id:988, must have at least 2 GPS points
#
# ...id:990, must have at least 2 GPS points
#
# ...id:992, must have at least 2 GPS points
#
# ...id:993, must have at least 2 GPS points
#
# ...id:994, must have at least 2 GPS points
#
# ...id:996, must have at least 2 GPS points
#
# ...id:997, must have at least 2 GPS points
#
# ...id:998, must have at least 2 GPS points
#
# ...id:1004, must have at least 2 GPS points
#
# ...id:1008, must have at least 2 GPS points
#
# ...id:1009, must have at least 2 GPS points
#
# ...id:1011, must have at least 2 GPS points
#
# ...id:1014, must have at least 2 GPS points
#
# ...id:1016, must have at least 2 GPS points
#
# ...id:1017, must have at least 2 GPS points
#
# ...id:1018, must have at least 2 GPS points
#
# ...id:1020, must have at least 2 GPS points
#
# ...id:1025, must have at least 2 GPS points
#
# ...id:1029, must have at least 2 GPS points
#
# ...id:1031, must have at least 2 GPS points
#
# ...id:1035, must have at least 2 GPS points
#
# ...id:1038, must have at least 2 GPS points
#
# ...id:1039, must have at least 2 GPS points
#
# ...id:1040, must have at least 2 GPS points
#
# ...id:1054, must have at least 2 GPS points
# ...id:1055, must have at least 2 GPS points
#
# ...id:1056, must have at least 2 GPS points
#
# ...id:1058, must have at least 2 GPS points
#
# ...id:1061, must have at least 2 GPS points
#
# ...id:1062, must have at least 2 GPS points
#
# ...id:1064, must have at least 2 GPS points
#
# ...id:1066, must have at least 2 GPS points
#
# ...id:1071, must have at least 2 GPS points
#
# ...id:1074, must have at least 2 GPS points
#
# ...id:1076, must have at least 2 GPS points
#
# ...id:1080, must have at least 2 GPS points
#
# ...id:1081, must have at least 2 GPS points
#
# ...id:1083, must have at least 2 GPS points
#
# ...id:1087, must have at least 2 GPS points
#
# ...id:1088, must have at least 2 GPS points
#
# ...id:1097, must have at least 2 GPS points
#
# ...id:1098, must have at least 2 GPS points
#
# ...id:1100, must have at least 2 GPS points
#
# ...id:1104, must have at least 2 GPS points
#
# ...id:1107, must have at least 2 GPS points
#
# ...id:1116, must have at least 2 GPS points
#
# ...id:1125, must have at least 2 GPS points
#
# ...id:1126, must have at least 2 GPS points
#
# ...id:1129, must have at least 2 GPS points
#
# ...id:1134, must have at least 2 GPS points
#
# ...id:1138, must have at least 2 GPS points
#
# ...id:1144, must have at least 2 GPS points
#
# ...id:1147, must have at least 2 GPS points
#
# ...id:1150, must have at least 2 GPS points
#
# ...id:1152, must have at least 2 GPS points
#
# ...id:1153, must have at least 2 GPS points
#
# ...id:1155, must have at least 2 GPS points
#
# ...id:1159, must have at least 2 GPS points
#
# ...id:1160, must have at least 2 GPS points
#
# ...id:1162, must have at least 2 GPS points
#
# ...id:1164, must have at least 2 GPS points
#
# ...id:1169, must have at least 2 GPS points
#
# ...id:1173, must have at least 2 GPS points
#
# ...id:1177, must have at least 2 GPS points
#
# ...id:1178, must have at least 2 GPS points
#
# ...id:1180, must have at least 2 GPS points
#
# ...id:1183, must have at least 2 GPS points
#
# ...id:1185, must have at least 2 GPS points
#
# ...id:1186, must have at least 2 GPS points
#
# ...id:1189, must have at least 2 GPS points
#
# ...id:1191, must have at least 2 GPS points
#
# ...id:1193, must have at least 2 GPS points
#
# ...id:1194, must have at least 2 GPS points
#
# ...id:1196, must have at least 2 GPS points
#
# ...id:1197, must have at least 2 GPS points
#
# ...id:1198, must have at least 2 GPS points
#
# ...id:1199, must have at least 2 GPS points
#
# ...id:1201, must have at least 2 GPS points
#
# ...id:1206, must have at least 2 GPS points
#
# ...id:1208, must have at least 2 GPS points
#
# ...id:1210, must have at least 2 GPS points
#
# ...id:1214, must have at least 2 GPS points
#
# ...id:1216, must have at least 2 GPS points
#
# ...id:1217, must have at least 2 GPS points
#
# ...id:1218, must have at least 2 GPS points
#
# ...id:1220, must have at least 2 GPS points
#
# ...id:1225, must have at least 2 GPS points
#
# ...id:1227, must have at least 2 GPS points
#
# ...id:1228, must have at least 2 GPS points
#
# ...id:1230, must have at least 2 GPS points
#
# ...id:1231, must have at least 2 GPS points
#
# ...id:1232, must have at least 2 GPS points
#
# (130666/217653) 60% in 00:00:01.639 - estimated end in 00:00:01.091
# ...id:1235, must have at least 2 GPS points
#
# ...id:1236, must have at least 2 GPS points
#
# ...id:1237, must have at least 2 GPS points
#
# ...id:1239, must have at least 2 GPS points
#
# ...id:1240, must have at least 2 GPS points
#
# ...id:1241, must have at least 2 GPS points
#
# ...id:1242, must have at least 2 GPS points
#
# ...id:1243, must have at least 2 GPS points
#
# ...id:1244, must have at least 2 GPS points
#
# ...id:1246, must have at least 2 GPS points
#
# ...id:1247, must have at least 2 GPS points
#
# ...id:1248, must have at least 2 GPS points
#
# ...id:1249, must have at least 2 GPS points
#
# ...id:1250, must have at least 2 GPS points
#
# ...id:1251, must have at least 2 GPS points
#
# ...id:1252, must have at least 2 GPS points
#
# ...id:1256, must have at least 2 GPS points
#
# ...id:1257, must have at least 2 GPS points
#
# ...id:1260, must have at least 2 GPS points
#
# ...id:1261, must have at least 2 GPS points
#
# ...id:1262, must have at least 2 GPS points
#
# ...id:1263, must have at least 2 GPS points
#
# ...id:1264, must have at least 2 GPS points
#
# ...id:1265, must have at least 2 GPS points
#
# ...id:1266, must have at least 2 GPS points
#
# ...id:1267, must have at least 2 GPS points
#
# ...id:1268, must have at least 2 GPS points
#
# ...id:1269, must have at least 2 GPS points
#
# ...id:1271, must have at least 2 GPS points
#
# ...id:1272, must have at least 2 GPS points
#
# ...id:1273, must have at least 2 GPS points
#
# ...id:1274, must have at least 2 GPS points
#
# ...id:1275, must have at least 2 GPS points
#
# ...id:1276, must have at least 2 GPS points
#
# ...id:1277, must have at least 2 GPS points
#
# ...id:1278, must have at least 2 GPS points
#
# ...id:1279, must have at least 2 GPS points
#
# ...id:1280, must have at least 2 GPS points
#
# ...id:1281, must have at least 2 GPS points
#
# ...id:1282, must have at least 2 GPS points
#
# ...id:1285, must have at least 2 GPS points
#
# ...id:1286, must have at least 2 GPS points
#
# ...id:1287, must have at least 2 GPS points
#
# ...id:1288, must have at least 2 GPS points
#
# ...id:1289, must have at least 2 GPS points
#
# ...id:1290, must have at least 2 GPS points
#
# ...id:1291, must have at least 2 GPS points
#
# ...id:1292, must have at least 2 GPS points
#
# ...id:1293, must have at least 2 GPS points
#
# ...id:1294, must have at least 2 GPS points
#
# ...id:1295, must have at least 2 GPS points
#
# ...id:1296, must have at least 2 GPS points
#
# ...id:1297, must have at least 2 GPS points
#
# ...id:1298, must have at least 2 GPS points
#
# ...id:1299, must have at least 2 GPS points
#
# ...id:1300, must have at least 2 GPS points
#
# ...id:1301, must have at least 2 GPS points
#
# ...id:1302, must have at least 2 GPS points
#
# ...id:1303, must have at least 2 GPS points
#
# ...id:1304, must have at least 2 GPS points
#
# ...id:1305, must have at least 2 GPS points
#
# ...id:1306, must have at least 2 GPS points
#
# ...id:1307, must have at least 2 GPS points
#
# ...id:1308, must have at least 2 GPS points
#
# ...id:1309, must have at least 2 GPS points
#
# ...id:1310, must have at least 2 GPS points
#
# ...id:1311, must have at least 2 GPS points
#
# ...id:1312, must have at least 2 GPS points
#
# ...id:1314, must have at least 2 GPS points
#
# ...id:1315, must have at least 2 GPS points
#
# ...id:1316, must have at least 2 GPS points
#
# ...id:1317, must have at least 2 GPS points
#
# ...id:1318, must have at least 2 GPS points
#
# ...id:1319, must have at least 2 GPS points
#
# ...id:1320, must have at least 2 GPS points
#
# ...id:1321, must have at least 2 GPS points
#
# ...id:1322, must have at least 2 GPS points
#
# ...id:1323, must have at least 2 GPS points
#
# ...id:1324, must have at least 2 GPS points
#
# ...id:1325, must have at least 2 GPS points
#
# ...id:1326, must have at least 2 GPS points
#
# ...id:1327, must have at least 2 GPS points
#
# ...id:1328, must have at least 2 GPS points
#
# ...id:1329, must have at least 2 GPS points
#
# ...id:1330, must have at least 2 GPS points
#
# ...id:1331, must have at least 2 GPS points
#
# ...id:1332, must have at least 2 GPS points
#
# ...id:1333, must have at least 2 GPS points
#
# ...id:1334, must have at least 2 GPS points
#
# ...id:1335, must have at least 2 GPS points
#
# ...id:1336, must have at least 2 GPS points
#
# ...id:1337, must have at least 2 GPS points
#
# ...id:1338, must have at least 2 GPS points
#
# ...id:1339, must have at least 2 GPS points
#
# ...id:1341, must have at least 2 GPS points
#
# ...id:1342, must have at least 2 GPS points
#
# ...id:1343, must have at least 2 GPS points
#
# ...id:1344, must have at least 2 GPS points
#
# ...id:1345, must have at least 2 GPS points
#
# ...id:1346, must have at least 2 GPS points
#
# ...id:1347, must have at least 2 GPS points
#
# ...id:1349, must have at least 2 GPS points
#
# ...id:1350, must have at least 2 GPS points
#
# ...id:1351, must have at least 2 GPS points
#
# ...id:1353, must have at least 2 GPS points
#
# ...id:1354, must have at least 2 GPS points
#
# ...id:1355, must have at least 2 GPS points
#
# ...id:1356, must have at least 2 GPS points
#
# ...id:1357, must have at least 2 GPS points
#
# ...id:1358, must have at least 2 GPS points
#
# ...id:1360, must have at least 2 GPS points
#
# ...id:1361, must have at least 2 GPS points
#
# ...id:1363, must have at least 2 GPS points
#
# ...id:1364, must have at least 2 GPS points
# ...id:1365, must have at least 2 GPS points
#
# ...id:1369, must have at least 2 GPS points
#
# ...id:1371, must have at least 2 GPS points
#
# ...id:1374, must have at least 2 GPS points
#
# ...id:1379, must have at least 2 GPS points
#
# ...id:1380, must have at least 2 GPS points
#
# ...id:1381, must have at least 2 GPS points
#
# ...id:1382, must have at least 2 GPS points
#
# ...id:1383, must have at least 2 GPS points
#
# ...id:1384, must have at least 2 GPS points
#
# ...id:1385, must have at least 2 GPS points
#
# ...id:1386, must have at least 2 GPS points
#
# ...id:1387, must have at least 2 GPS points
#
# ...id:1388, must have at least 2 GPS points
#
# ...id:1389, must have at least 2 GPS points
#
# ...id:1390, must have at least 2 GPS points
#
# ...id:1391, must have at least 2 GPS points
#
# ...id:1392, must have at least 2 GPS points
#
# ...id:1393, must have at least 2 GPS points
#
# ...id:1394, must have at least 2 GPS points
#
# ...id:1396, must have at least 2 GPS points
#
# ...id:1397, must have at least 2 GPS points
#
# ...id:1398, must have at least 2 GPS points
#
# ...id:1399, must have at least 2 GPS points
#
# ...id:1400, must have at least 2 GPS points
#
# ...id:1401, must have at least 2 GPS points
#
# ...id:1402, must have at least 2 GPS points
#
# ...id:1403, must have at least 2 GPS points
#
# ...id:1404, must have at least 2 GPS points
#
# ...id:1405, must have at least 2 GPS points
#
# ...id:1406, must have at least 2 GPS points
#
# ...id:1407, must have at least 2 GPS points
#
# ...id:1409, must have at least 2 GPS points
#
# ...id:1410, must have at least 2 GPS points
#
# ...id:1413, must have at least 2 GPS points
#
# ...id:1414, must have at least 2 GPS points
#
# ...id:1415, must have at least 2 GPS points
#
# ...id:1416, must have at least 2 GPS points
#
# ...id:1418, must have at least 2 GPS points
#
# ...id:1419, must have at least 2 GPS points
#
# ...id:1420, must have at least 2 GPS points
#
# ...id:1421, must have at least 2 GPS points
#
# ...id:1422, must have at least 2 GPS points
#
# ...id:1423, must have at least 2 GPS points
#
# ...id:1424, must have at least 2 GPS points
#
# ...id:1426, must have at least 2 GPS points
#
# ...id:1427, must have at least 2 GPS points
#
# ...id:1428, must have at least 2 GPS points
#
# ...id:1429, must have at least 2 GPS points
#
# ...id:1431, must have at least 2 GPS points
#
# ...id:1432, must have at least 2 GPS points
#
# ...id:1433, must have at least 2 GPS points
#
# ...id:1434, must have at least 2 GPS points
#
# ...id:1435, must have at least 2 GPS points
#
# ...id:1436, must have at least 2 GPS points
#
# ...id:1437, must have at least 2 GPS points
#
# ...id:1438, must have at least 2 GPS points
#
# ...id:1440, must have at least 2 GPS points
#
# ...id:1443, must have at least 2 GPS points
#
# ...id:1444, must have at least 2 GPS points
#
# ...id:1445, must have at least 2 GPS points
#
# ...id:1446, must have at least 2 GPS points
#
# ...id:1448, must have at least 2 GPS points
#
# ...id:1449, must have at least 2 GPS points
#
# ...id:1450, must have at least 2 GPS points
#
# ...id:1451, must have at least 2 GPS points
#
# ...id:1454, must have at least 2 GPS points
#
# ...id:1455, must have at least 2 GPS points
#
# ...id:1456, must have at least 2 GPS points
#
# ...id:1457, must have at least 2 GPS points
#
# ...id:1458, must have at least 2 GPS points
#
# ...id:1459, must have at least 2 GPS points
#
# ...id:1460, must have at least 2 GPS points
#
# ...id:1461, must have at least 2 GPS points
#
# ...id:1462, must have at least 2 GPS points
#
# ...id:1463, must have at least 2 GPS points
#
# ...id:1464, must have at least 2 GPS points
#
# ...id:1465, must have at least 2 GPS points
#
# ...id:1466, must have at least 2 GPS points
#
# ...id:1469, must have at least 2 GPS points
#
# ...id:1470, must have at least 2 GPS points
#
# ...id:1471, must have at least 2 GPS points
#
# ...id:1472, must have at least 2 GPS points
#
# ...id:1473, must have at least 2 GPS points
#
# ...id:1474, must have at least 2 GPS points
#
# ...id:1476, must have at least 2 GPS points
#
# ...id:1478, must have at least 2 GPS points
#
# ...id:1480, must have at least 2 GPS points
#
# ...id:1483, must have at least 2 GPS points
#
# ...id:1484, must have at least 2 GPS points
#
# ...id:1486, must have at least 2 GPS points
#
# ...id:1488, must have at least 2 GPS points
#
# ...id:1489, must have at least 2 GPS points
#
# ...id:1490, must have at least 2 GPS points
#
# ...id:1491, must have at least 2 GPS points
#
# ...id:1492, must have at least 2 GPS points
#
# ...id:1493, must have at least 2 GPS points
#
# ...id:1494, must have at least 2 GPS points
#
# ...id:1495, must have at least 2 GPS points
#
# ...id:1496, must have at least 2 GPS points
#
# ...id:1497, must have at least 2 GPS points
#
# ...id:1498, must have at least 2 GPS points
#
# ...id:1499, must have at least 2 GPS points
#
# ...id:1500, must have at least 2 GPS points
#
# ...id:1501, must have at least 2 GPS points
#
# ...id:1502, must have at least 2 GPS points
#
# ...id:1503, must have at least 2 GPS points
#
# ...id:1505, must have at least 2 GPS points
#
# ...id:1506, must have at least 2 GPS points
#
# ...id:1507, must have at least 2 GPS points
#
# ...id:1508, must have at least 2 GPS points
#
# ...id:1510, must have at least 2 GPS points
#
# ...id:1511, must have at least 2 GPS points
#
# ...id:1512, must have at least 2 GPS points
#
# ...id:1513, must have at least 2 GPS points
#
# ...id:1514, must have at least 2 GPS points
#
# ...id:1515, must have at least 2 GPS points
#
# ...id:1516, must have at least 2 GPS points
#
# ...id:1517, must have at least 2 GPS points
#
# ...id:1520, must have at least 2 GPS points
#
# ...id:1521, must have at least 2 GPS points
#
# ...id:1522, must have at least 2 GPS points
#
# ...id:1523, must have at least 2 GPS points
#
# ...id:1524, must have at least 2 GPS points
#
# ...id:1525, must have at least 2 GPS points
#
# ...id:1527, must have at least 2 GPS points
#
# ...id:1528, must have at least 2 GPS points
#
# ...id:1529, must have at least 2 GPS points
#
# ...id:1531, must have at least 2 GPS points
#
# ...id:1532, must have at least 2 GPS points
#
# ...id:1535, must have at least 2 GPS points
#
# ...id:1536, must have at least 2 GPS points
#
# ...id:1537, must have at least 2 GPS points
#
# ...id:1538, must have at least 2 GPS points
#
# ...id:1539, must have at least 2 GPS points
#
# ...id:1540, must have at least 2 GPS points
#
# ...id:1541, must have at least 2 GPS points
#
# ...id:1542, must have at least 2 GPS points
#
# ...id:1543, must have at least 2 GPS points
#
# ...id:1544, must have at least 2 GPS points
#
# ...id:1545, must have at least 2 GPS points
#
# ...id:1546, must have at least 2 GPS points
#
# ...id:1547, must have at least 2 GPS points
#
# ...id:1548, must have at least 2 GPS points
#
# ...id:1549, must have at least 2 GPS points
#
# ...id:1550, must have at least 2 GPS points
#
# ...id:1551, must have at least 2 GPS points
#
# ...id:1552, must have at least 2 GPS points
#
# ...id:1553, must have at least 2 GPS points
#
# ...id:1554, must have at least 2 GPS points
#
# ...id:1556, must have at least 2 GPS points
#
# ...id:1557, must have at least 2 GPS points
#
# ...id:1558, must have at least 2 GPS points
#
# ...id:1559, must have at least 2 GPS points
#
# ...id:1560, must have at least 2 GPS points
#
# ...id:1563, must have at least 2 GPS points
#
# ...id:1564, must have at least 2 GPS points
#
# ...id:1565, must have at least 2 GPS points
#
# ...id:1567, must have at least 2 GPS points
#
# ...id:1568, must have at least 2 GPS points
#
# ...id:1569, must have at least 2 GPS points
#
# ...id:1570, must have at least 2 GPS points
#
# ...id:1571, must have at least 2 GPS points
#
# ...id:1572, must have at least 2 GPS points
#
# ...id:1573, must have at least 2 GPS points
#
# ...id:1574, must have at least 2 GPS points
#
# ...id:1576, must have at least 2 GPS points
#
# ...id:1577, must have at least 2 GPS points
#
# ...id:1578, must have at least 2 GPS points
#
# ...id:1579, must have at least 2 GPS points
#
# ...id:1580, must have at least 2 GPS points
#
# ...id:1582, must have at least 2 GPS points
#
# ...id:1583, must have at least 2 GPS points
#
# ...id:1584, must have at least 2 GPS points
#
# ...id:1585, must have at least 2 GPS points
#
# ...id:1586, must have at least 2 GPS points
#
# ...id:1587, must have at least 2 GPS points
#
# ...id:1588, must have at least 2 GPS points
#
# ...id:1589, must have at least 2 GPS points
#
# ...id:1590, must have at least 2 GPS points
#
# ...id:1591, must have at least 2 GPS points
#
# ...id:1592, must have at least 2 GPS points
#
# ...id:1593, must have at least 2 GPS points
# ...id:1595, must have at least 2 GPS points
#
# ...id:1596, must have at least 2 GPS points
#
# ...id:1597, must have at least 2 GPS points
#
# ...id:1598, must have at least 2 GPS points
#
# ...id:1599, must have at least 2 GPS points
#
# ...id:1600, must have at least 2 GPS points
#
# ...id:1601, must have at least 2 GPS points
#
# ...id:1602, must have at least 2 GPS points
#
# ...id:1604, must have at least 2 GPS points
#
# ...id:1606, must have at least 2 GPS points
#
# ...id:1607, must have at least 2 GPS points
#
# ...id:1608, must have at least 2 GPS points
#
# ...id:1609, must have at least 2 GPS points
#
# ...id:1610, must have at least 2 GPS points
#
# ...id:1611, must have at least 2 GPS points
#
# ...id:1612, must have at least 2 GPS points
#
# ...id:1613, must have at least 2 GPS points
#
# ...id:1615, must have at least 2 GPS points
#
# ...id:1617, must have at least 2 GPS points
#
# ...id:1618, must have at least 2 GPS points
#
# ...id:1619, must have at least 2 GPS points
#
# ...id:1620, must have at least 2 GPS points
#
# ...id:1622, must have at least 2 GPS points
#
# ...id:1623, must have at least 2 GPS points
#
# ...id:1624, must have at least 2 GPS points
#
# ...id:1625, must have at least 2 GPS points
#
# ...id:1626, must have at least 2 GPS points
#
# ...id:1627, must have at least 2 GPS points
#
# ...id:1628, must have at least 2 GPS points
#
# ...id:1629, must have at least 2 GPS points
#
# ...id:1630, must have at least 2 GPS points
#
# ...id:1632, must have at least 2 GPS points
#
# ...id:1633, must have at least 2 GPS points
#
# ...id:1634, must have at least 2 GPS points
#
# ...id:1635, must have at least 2 GPS points
#
# ...id:1636, must have at least 2 GPS points
#
# ...id:1637, must have at least 2 GPS points
#
# ...id:1639, must have at least 2 GPS points
#
# ...id:1644, must have at least 2 GPS points
#
# ...id:1647, must have at least 2 GPS points
#
# ...id:1648, must have at least 2 GPS points
#
# ...id:1649, must have at least 2 GPS points
#
# ...id:1652, must have at least 2 GPS points
#
# ...id:1653, must have at least 2 GPS points
#
# ...id:1654, must have at least 2 GPS points
#
# ...id:1658, must have at least 2 GPS points
#
# ...id:1660, must have at least 2 GPS points
#
# ...id:1661, must have at least 2 GPS points
#
# ...id:1662, must have at least 2 GPS points
#
# ...id:1664, must have at least 2 GPS points
#
# ...id:1665, must have at least 2 GPS points
#
# ...id:1667, must have at least 2 GPS points
#
# ...id:1671, must have at least 2 GPS points
#
# ...id:1675, must have at least 2 GPS points
#
# ...id:1684, must have at least 2 GPS points
#
# ...id:1686, must have at least 2 GPS points
#
# ...id:1692, must have at least 2 GPS points
#
# ...id:1695, must have at least 2 GPS points
#
# ...id:1696, must have at least 2 GPS points
#
# ...id:1697, must have at least 2 GPS points
#
# ...id:1698, must have at least 2 GPS points
#
# ...id:1699, must have at least 2 GPS points
#
# ...id:1702, must have at least 2 GPS points
#
# ...id:1703, must have at least 2 GPS points
#
# ...id:1704, must have at least 2 GPS points
#
# ...id:1706, must have at least 2 GPS points
#
# ...id:1711, must have at least 2 GPS points
#
# ...id:1713, must have at least 2 GPS points
#
# ...id:1714, must have at least 2 GPS points
#
# ...id:1721, must have at least 2 GPS points
#
# ...id:1725, must have at least 2 GPS points
#
# ...id:1726, must have at least 2 GPS points
#
# ...id:1731, must have at least 2 GPS points
#
# ...id:1733, must have at least 2 GPS points
#
# ...id:1737, must have at least 2 GPS points
#
# ...id:1738, must have at least 2 GPS points
#
# ...id:1739, must have at least 2 GPS points
#
# ...id:1740, must have at least 2 GPS points
#
# ...id:1742, must have at least 2 GPS points
#
# ...id:1743, must have at least 2 GPS points
#
# ...id:1744, must have at least 2 GPS points
#
# ...id:1746, must have at least 2 GPS points
#
# ...id:1749, must have at least 2 GPS points
#
# ...id:1750, must have at least 2 GPS points
#
# ...id:1755, must have at least 2 GPS points
#
# ...id:1758, must have at least 2 GPS points
#
# ...id:1759, must have at least 2 GPS points
#
# ...id:1762, must have at least 2 GPS points
#
# ...id:1765, must have at least 2 GPS points
#
# ...id:1770, must have at least 2 GPS points
#
# ...id:1777, must have at least 2 GPS points
#
# ...id:1778, must have at least 2 GPS points
#
# ...id:1779, must have at least 2 GPS points
#
# ...id:1780, must have at least 2 GPS points
#
# ...id:1786, must have at least 2 GPS points
#
# ...id:1787, must have at least 2 GPS points
#
# ...id:1788, must have at least 2 GPS points
#
# ...id:1792, must have at least 2 GPS points
#
# ...id:1795, must have at least 2 GPS points
#
# ...id:1797, must have at least 2 GPS points
#
# ...id:1799, must have at least 2 GPS points
#
# ...id:1801, must have at least 2 GPS points
#
# ...id:1803, must have at least 2 GPS points
#
# ...id:1804, must have at least 2 GPS points
#
# ...id:1805, must have at least 2 GPS points
#
# ...id:1806, must have at least 2 GPS points
#
# ...id:1807, must have at least 2 GPS points
#
# ...id:1809, must have at least 2 GPS points
#
# ...id:1810, must have at least 2 GPS points
#
# ...id:1812, must have at least 2 GPS points
#
# ...id:1813, must have at least 2 GPS points
#
# ...id:1814, must have at least 2 GPS points
#
# ...id:1815, must have at least 2 GPS points
#
# ...id:1816, must have at least 2 GPS points
#
# ...id:1817, must have at least 2 GPS points
#
# ...id:1822, must have at least 2 GPS points
#
# ...id:1824, must have at least 2 GPS points
#
# ...id:1825, must have at least 2 GPS points
#
# ...id:1826, must have at least 2 GPS points
#
# ...id:1827, must have at least 2 GPS points
#
# ...id:1829, must have at least 2 GPS points
#
# ...id:1830, must have at least 2 GPS points
#
# ...id:1831, must have at least 2 GPS points
#
# ...id:1838, must have at least 2 GPS points
#
# ...id:1839, must have at least 2 GPS points
#
# ...id:1841, must have at least 2 GPS points
#
# ...id:1842, must have at least 2 GPS points
#
# ...id:1845, must have at least 2 GPS points
#
# ...id:1846, must have at least 2 GPS points
#
# ...id:1847, must have at least 2 GPS points
#
# ...id:1848, must have at least 2 GPS points
#
# ...id:1849, must have at least 2 GPS points
#
# ...id:1850, must have at least 2 GPS points
#
# ...id:1851, must have at least 2 GPS points
#
# ...id:1852, must have at least 2 GPS points
#
# ...id:1853, must have at least 2 GPS points
#
# ...id:1854, must have at least 2 GPS points
#
# ...id:1859, must have at least 2 GPS points
#
# ...id:1864, must have at least 2 GPS points
#
# ...id:1866, must have at least 2 GPS points
#
# ...id:1867, must have at least 2 GPS points
#
# ...id:1868, must have at least 2 GPS points
#
# ...id:1869, must have at least 2 GPS points
#
# ...id:1873, must have at least 2 GPS points
#
# ...id:1877, must have at least 2 GPS points
#
# ...id:1878, must have at least 2 GPS points
#
# ...id:1880, must have at least 2 GPS points
#
# ...id:1881, must have at least 2 GPS points
#
# ...id:1884, must have at least 2 GPS points
#
# ...id:1885, must have at least 2 GPS points
#
# ...id:1890, must have at least 2 GPS points
#
# ...id:1891, must have at least 2 GPS points
#
# ...id:1892, must have at least 2 GPS points
#
# ...id:1895, must have at least 2 GPS points
#
# ...id:1896, must have at least 2 GPS points
#
# ...id:1900, must have at least 2 GPS points
#
# ...id:1905, must have at least 2 GPS points
#
# ...id:1925, must have at least 2 GPS points
#
# ...id:1928, must have at least 2 GPS points
#
# ...id:1929, must have at least 2 GPS points
#
# ...id:1930, must have at least 2 GPS points
#
# ...id:1935, must have at least 2 GPS points
#
# ...id:1942, must have at least 2 GPS points
#
# ...id:1958, must have at least 2 GPS points
#
# ...id:1959, must have at least 2 GPS points
#
# ...id:1960, must have at least 2 GPS points
#
# ...id:1961, must have at least 2 GPS points
#
# ...id:1969, must have at least 2 GPS points
#
# ...id:1970, must have at least 2 GPS points
#
# ...id:1971, must have at least 2 GPS points
#
# ...id:1972, must have at least 2 GPS points
#
# ...id:1976, must have at least 2 GPS points
#
# ...id:1978, must have at least 2 GPS points
#
# ...id:1988, must have at least 2 GPS points
#
# ...id:1990, must have at least 2 GPS points
#
# ...id:1991, must have at least 2 GPS points
#
# ...id:1992, must have at least 2 GPS points
#
# ...id:1993, must have at least 2 GPS points
#
# ...id:2002, must have at least 2 GPS points
#
# ...id:2005, must have at least 2 GPS points
#
# ...id:2006, must have at least 2 GPS points
#
# ...id:2013, must have at least 2 GPS points
#
# ...id:2014, must have at least 2 GPS points
# ...id:2015, must have at least 2 GPS points
#
# ...id:2016, must have at least 2 GPS points
#
# ...id:2017, must have at least 2 GPS points
#
# ...id:2018, must have at least 2 GPS points
#
# ...id:2019, must have at least 2 GPS points
#
# ...id:2020, must have at least 2 GPS points
#
# ...id:2021, must have at least 2 GPS points
#
# ...id:2022, must have at least 2 GPS points
#
# ...id:2023, must have at least 2 GPS points
#
# ...id:2024, must have at least 2 GPS points
#
# ...id:2025, must have at least 2 GPS points
#
# ...id:2026, must have at least 2 GPS points
#
# ...id:2027, must have at least 2 GPS points
#
# ...id:2028, must have at least 2 GPS points
#
# ...id:2031, must have at least 2 GPS points
#
# ...id:2032, must have at least 2 GPS points
#
# ...id:2033, must have at least 2 GPS points
#
# ...id:2034, must have at least 2 GPS points
#
# ...id:2036, must have at least 2 GPS points
#
# ...id:2037, must have at least 2 GPS points
#
# ...id:2038, must have at least 2 GPS points
#
# ...id:2039, must have at least 2 GPS points
#
# ...id:2040, must have at least 2 GPS points
#
# ...id:2043, must have at least 2 GPS points
#
# ...id:2046, must have at least 2 GPS points
#
# ...id:2049, must have at least 2 GPS points
#
# ...id:2051, must have at least 2 GPS points
#
# ...id:2053, must have at least 2 GPS points
#
# ...id:2060, must have at least 2 GPS points
#
# ...id:2061, must have at least 2 GPS points
#
# ...id:2064, must have at least 2 GPS points
#
# ...id:2067, must have at least 2 GPS points
#
# ...id:2072, must have at least 2 GPS points
#
# ...id:2073, must have at least 2 GPS points
#
# ...id:2081, must have at least 2 GPS points
#
# ...id:2082, must have at least 2 GPS points
#
# ...id:2083, must have at least 2 GPS points
#
# ...id:2084, must have at least 2 GPS points
#
# ...id:2088, must have at least 2 GPS points
#
# ...id:2091, must have at least 2 GPS points
#
# ...id:2092, must have at least 2 GPS points
#
# ...id:2094, must have at least 2 GPS points
#
# ...id:2095, must have at least 2 GPS points
#
# ...id:2098, must have at least 2 GPS points
#
# ...id:2101, must have at least 2 GPS points
#
# ...id:2106, must have at least 2 GPS points
#
# ...id:2107, must have at least 2 GPS points
#
# ...id:2111, must have at least 2 GPS points
#
# ...id:2112, must have at least 2 GPS points
#
# ...id:2113, must have at least 2 GPS points
#
# ...id:2121, must have at least 2 GPS points
#
# ...id:2127, must have at least 2 GPS points
#
# ...id:2139, must have at least 2 GPS points
#
# ...id:2141, must have at least 2 GPS points
#
# ...id:2143, must have at least 2 GPS points
#
# ...id:2145, must have at least 2 GPS points
#
# ...id:2150, must have at least 2 GPS points
#
# ...id:2151, must have at least 2 GPS points
#
# ...id:2152, must have at least 2 GPS points
#
# ...id:2153, must have at least 2 GPS points
#
# ...id:2154, must have at least 2 GPS points
#
# ...id:2156, must have at least 2 GPS points
#
# ...id:2157, must have at least 2 GPS points
#
# ...id:2158, must have at least 2 GPS points
#
# ...id:2159, must have at least 2 GPS points
#
# ...id:2161, must have at least 2 GPS points
#
# ...id:2162, must have at least 2 GPS points
#
# ...id:2164, must have at least 2 GPS points
#
# ...id:2166, must have at least 2 GPS points
#
# ...id:2167, must have at least 2 GPS points
#
# ...id:2168, must have at least 2 GPS points
#
# ...id:2170, must have at least 2 GPS points
#
# ...id:2171, must have at least 2 GPS points
#
# ...id:2172, must have at least 2 GPS points
#
# ...id:2173, must have at least 2 GPS points
#
# ...id:2174, must have at least 2 GPS points
#
# ...id:2175, must have at least 2 GPS points
#
# ...id:2176, must have at least 2 GPS points
#
# ...id:2177, must have at least 2 GPS points
#
# ...id:2178, must have at least 2 GPS points
#
# ...id:2179, must have at least 2 GPS points
#
# ...id:2180, must have at least 2 GPS points
#
# ...id:2181, must have at least 2 GPS points
#
# ...id:2182, must have at least 2 GPS points
#
# ...id:2183, must have at least 2 GPS points
#
# ...id:2187, must have at least 2 GPS points
#
# ...id:2188, must have at least 2 GPS points
#
# ...id:2189, must have at least 2 GPS points
#
# ...id:2190, must have at least 2 GPS points
#
# ...id:2192, must have at least 2 GPS points
#
# ...id:2193, must have at least 2 GPS points
#
# ...id:2194, must have at least 2 GPS points
#
# ...id:2195, must have at least 2 GPS points
#
# ...id:2197, must have at least 2 GPS points
#
# ...id:2198, must have at least 2 GPS points
#
# ...id:2199, must have at least 2 GPS points
#
# ...id:2200, must have at least 2 GPS points
#
# ...id:2201, must have at least 2 GPS points
#
# ...id:2202, must have at least 2 GPS points
#
# ...id:2204, must have at least 2 GPS points
#
# ...id:2205, must have at least 2 GPS points
#
# ...id:2206, must have at least 2 GPS points
#
# ...id:2207, must have at least 2 GPS points
#
# ...id:2208, must have at least 2 GPS points
#
# ...id:2209, must have at least 2 GPS points
#
# ...id:2210, must have at least 2 GPS points
#
# ...id:2211, must have at least 2 GPS points
#
# ...id:2212, must have at least 2 GPS points
#
# ...id:2214, must have at least 2 GPS points
#
# ...id:2215, must have at least 2 GPS points
#
# ...id:2216, must have at least 2 GPS points
#
# ...id:2217, must have at least 2 GPS points
#
# ...id:2218, must have at least 2 GPS points
#
# ...id:2219, must have at least 2 GPS points
#
# ...id:2220, must have at least 2 GPS points
#
# ...id:2221, must have at least 2 GPS points
#
# ...id:2222, must have at least 2 GPS points
#
# ...id:2223, must have at least 2 GPS points
#
# ...id:2224, must have at least 2 GPS points
#
# ...id:2225, must have at least 2 GPS points
#
# ...id:2226, must have at least 2 GPS points
#
# ...id:2227, must have at least 2 GPS points
#
# ...id:2228, must have at least 2 GPS points
#
# ...id:2229, must have at least 2 GPS points
#
# ...id:2230, must have at least 2 GPS points
#
# ...id:2231, must have at least 2 GPS points
#
# ...id:2232, must have at least 2 GPS points
#
# ...id:2233, must have at least 2 GPS points
#
# ...id:2234, must have at least 2 GPS points
#
# ...id:2235, must have at least 2 GPS points
#
# ...id:2236, must have at least 2 GPS points
#
# ...id:2237, must have at least 2 GPS points
#
# ...id:2238, must have at least 2 GPS points
#
# ...id:2239, must have at least 2 GPS points
#
# ...id:2240, must have at least 2 GPS points
#
# ...id:2242, must have at least 2 GPS points
#
# ...id:2243, must have at least 2 GPS points
#
# ...id:2244, must have at least 2 GPS points
#
# ...id:2245, must have at least 2 GPS points
#
# ...id:2246, must have at least 2 GPS points
#
# ...id:2247, must have at least 2 GPS points
#
# ...id:2248, must have at least 2 GPS points
#
# ...id:2249, must have at least 2 GPS points
#
# ...id:2250, must have at least 2 GPS points
#
# ...id:2251, must have at least 2 GPS points
#
# ...id:2253, must have at least 2 GPS points
#
# ...id:2254, must have at least 2 GPS points
#
# ...id:2255, must have at least 2 GPS points
#
# ...id:2256, must have at least 2 GPS points
#
# ...id:2257, must have at least 2 GPS points
#
# ...id:2258, must have at least 2 GPS points
#
# ...id:2259, must have at least 2 GPS points
#
# ...id:2260, must have at least 2 GPS points
#
# ...
#
# ...id:4066, must have at least 2 GPS points
#
# ...id:4067, must have at least 2 GPS points
#
# ...id:4068, must have at least 2 GPS points
#
# ...id:4069, must have at least 2 GPS points
#
# ...id:4070, must have at least 2 GPS points
#
# ...id:4071, must have at least 2 GPS points
#
# ...id:4072, must have at least 2 GPS points
#
# ...id:4073, must have at least 2 GPS points
#
# ...id:4074, must have at least 2 GPS points
#
# ...id:4075, must have at least 2 GPS points
#
# ...id:4076, must have at least 2 GPS points
#
# ...id:4077, must have at least 2 GPS points
#
# ...id:4078, must have at least 2 GPS points
#
# ...id:4079, must have at least 2 GPS points
#
# ...id:4080, must have at least 2 GPS points
#
# ...id:4081, must have at least 2 GPS points
#
# ...id:4082, must have at least 2 GPS points
#
# ...id:4083, must have at least 2 GPS points
#
# ...id:4084, must have at least 2 GPS points
#
# ...id:4085, must have at least 2 GPS points
#
# ...id:4086, must have at least 2 GPS points
#
# ...id:4087, must have at least 2 GPS points
#
# ...id:4088, must have at least 2 GPS points
#
# ...id:4089, must have at least 2 GPS points
#
# ...id:4090, must have at least 2 GPS points
#
# ...id:4091, must have at least 2 GPS points
#
# ...id:4092, must have at least 2 GPS points
#
# ...id:4093, must have at least 2 GPS points
#
# ...id:4094, must have at least 2 GPS points
#
# ...id:4095, must have at least 2 GPS points
#
# ...id:4096, must have at least 2 GPS points
#
# ...id:4097, must have at least 2 GPS points
#
# ...id:4098, must have at least 2 GPS points
#
# ...id:4099, must have at least 2 GPS points
#
# ...id:4100, must have at least 2 GPS points
#
# ...id:4101, must have at least 2 GPS points
#
# ...id:4102, must have at least 2 GPS points
#
# ...id:4103, must have at least 2 GPS points
#
# ...id:4104, must have at least 2 GPS points
#
# ...id:4105, must have at least 2 GPS points
#
# ...id:4106, must have at least 2 GPS points
#
# ...id:4107, must have at least 2 GPS points
#
# ...id:4108, must have at least 2 GPS points
#
# ...id:4109, must have at least 2 GPS points
#
# ...id:4110, must have at least 2 GPS points
#
# ...id:4111, must have at least 2 GPS points
#
# ...id:4112, must have at least 2 GPS points
#
# ...id:4113, must have at least 2 GPS points
#
# ...id:4114, must have at least 2 GPS points
#
# ...id:4115, must have at least 2 GPS points
#
# ...id:4119, must have at least 2 GPS points
#
# ...id:4122, must have at least 2 GPS points
#
# ...id:4124, must have at least 2 GPS points
#
# ...id:4125, must have at least 2 GPS points
# ...id:4126, must have at least 2 GPS points
#
# ...id:4127, must have at least 2 GPS points
#
# ...id:4128, must have at least 2 GPS points
#
# ...id:4130, must have at least 2 GPS points
#
# ...id:4131, must have at least 2 GPS points
#
# ...id:4132, must have at least 2 GPS points
#
# ...id:4133, must have at least 2 GPS points
#
# ...id:4134, must have at least 2 GPS points
#
# ...id:4135, must have at least 2 GPS points
#
# ...id:4136, must have at least 2 GPS points
#
# ...id:4137, must have at least 2 GPS points
#
# ...id:4138, must have at least 2 GPS points
#
# ...id:4139, must have at least 2 GPS points
#
# ...id:4141, must have at least 2 GPS points
#
# ...id:4142, must have at least 2 GPS points
#
# ...id:4144, must have at least 2 GPS points
#
# ...id:4145, must have at least 2 GPS points
#
# ...id:4146, must have at least 2 GPS points
#
# ...id:4147, must have at least 2 GPS points
#
# ...id:4148, must have at least 2 GPS points
#
# ...id:4150, must have at least 2 GPS points
#
# ...id:4151, must have at least 2 GPS points
#
# ...id:4152, must have at least 2 GPS points
#
# ...id:4153, must have at least 2 GPS points
#
# ...id:4154, must have at least 2 GPS points
#
# ...id:4156, must have at least 2 GPS points
#
# ...id:4158, must have at least 2 GPS points
#
# ...id:4159, must have at least 2 GPS points
#
# ...id:4160, must have at least 2 GPS points
#
# ...id:4161, must have at least 2 GPS points
#
# ...id:4162, must have at least 2 GPS points
#
# ...id:4163, must have at least 2 GPS points
#
# ...id:4164, must have at least 2 GPS points
#
# ...id:4165, must have at least 2 GPS points
#
# ...id:4167, must have at least 2 GPS points
#
# ...id:4168, must have at least 2 GPS points
#
# ...id:4169, must have at least 2 GPS points
#
# ...id:4170, must have at least 2 GPS points
#
# ...id:4171, must have at least 2 GPS points
#
# ...id:4172, must have at least 2 GPS points
#
# ...id:4173, must have at least 2 GPS points
#
# ...id:4174, must have at least 2 GPS points
#
# ...id:4175, must have at least 2 GPS points
#
# ...id:4185, must have at least 2 GPS points
#
# ...id:4187, must have at least 2 GPS points
#
# ...id:4188, must have at least 2 GPS points
#
# ...id:4196, must have at least 2 GPS points
#
# ...id:4198, must have at least 2 GPS points
#
# ...id:4199, must have at least 2 GPS points
#
# ...id:4204, must have at least 2 GPS points
#
# ...id:4208, must have at least 2 GPS points
#
# ...id:4212, must have at least 2 GPS points
#
# ...id:4213, must have at least 2 GPS points
#
# ...id:4219, must have at least 2 GPS points
#
# ...id:4231, must have at least 2 GPS points
#
# ...id:4237, must have at least 2 GPS points
#
# ...id:4239, must have at least 2 GPS points
#
# ...id:4243, must have at least 2 GPS points
#
# ...id:4248, must have at least 2 GPS points
#
# ...id:4249, must have at least 2 GPS points
#
# ...id:4250, must have at least 2 GPS points
#
# ...id:4253, must have at least 2 GPS points
#
# ...id:4257, must have at least 2 GPS points
#
# ...id:4258, must have at least 2 GPS points
#
# ...id:4261, must have at least 2 GPS points
#
# ...id:4275, must have at least 2 GPS points
#
# ...id:4284, must have at least 2 GPS points
#
# ...id:4286, must have at least 2 GPS points
#
# ...id:4289, must have at least 2 GPS points
#
# ...id:4293, must have at least 2 GPS points
#
# ...id:4295, must have at least 2 GPS points
#
# ...id:4301, must have at least 2 GPS points
#
# ...id:4304, must have at least 2 GPS points
#
# ...id:4307, must have at least 2 GPS points
#
# ...id:4309, must have at least 2 GPS points
#
# ...id:4313, must have at least 2 GPS points
#
# ...id:4314, must have at least 2 GPS points
#
# ...id:4316, must have at least 2 GPS points
#
# ...id:4318, must have at least 2 GPS points
#
# ...id:4325, must have at least 2 GPS points
#
# ...id:4326, must have at least 2 GPS points
#
# ...id:4327, must have at least 2 GPS points
#
# ...id:4336, must have at least 2 GPS points
#
# ...id:4337, must have at least 2 GPS points
#
# ...id:4338, must have at least 2 GPS points
#
# ...id:4339, must have at least 2 GPS points
#
# ...id:4345, must have at least 2 GPS points
#
# ...id:4348, must have at least 2 GPS points
#
# ...id:4350, must have at least 2 GPS points
#
# ...id:4351, must have at least 2 GPS points
#
# ...id:4353, must have at least 2 GPS points
#
# ...id:4354, must have at least 2 GPS points
#
# ...id:4356, must have at least 2 GPS points
#
# ...id:4357, must have at least 2 GPS points
#
# ...id:4358, must have at least 2 GPS points
#
# ...id:4360, must have at least 2 GPS points
#
# ...id:4371, must have at least 2 GPS points
#
# ...id:4373, must have at least 2 GPS points
#
# ...id:4374, must have at least 2 GPS points
#
# ...id:4375, must have at least 2 GPS points
#
# ...id:4377, must have at least 2 GPS points
#
# ...id:4378, must have at least 2 GPS points
#
# ...id:4379, must have at least 2 GPS points
#
# ...id:4380, must have at least 2 GPS points
#
# ...id:4382, must have at least 2 GPS points
#
# ...id:4384, must have at least 2 GPS points
#
# ...id:4386, must have at least 2 GPS points
#
# ...id:4393, must have at least 2 GPS points
#
# ...id:4394, must have at least 2 GPS points
#
# ...id:4395, must have at least 2 GPS points
#
# ...id:4403, must have at least 2 GPS points
#
# ...id:4410, must have at least 2 GPS points
#
# ...id:4415, must have at least 2 GPS points
#
# ...id:4424, must have at least 2 GPS points
#
# ...id:4430, must have at least 2 GPS points
#
# ...id:4446, must have at least 2 GPS points
#
# ...id:4447, must have at least 2 GPS points
#
# ...id:4448, must have at least 2 GPS points
#
# ...id:4449, must have at least 2 GPS points
#
# ...id:4450, must have at least 2 GPS points
#
# ...id:4473, must have at least 2 GPS points
#
# ...id:4475, must have at least 2 GPS points
#
# ...id:4478, must have at least 2 GPS points
#
# ...id:4480, must have at least 2 GPS points
#
# ...id:4482, must have at least 2 GPS points
#
# ...id:4484, must have at least 2 GPS points
#
# ...id:4494, must have at least 2 GPS points
#
# ...id:4497, must have at least 2 GPS points
#
# ...id:4500, must have at least 2 GPS points
#
# ...id:4501, must have at least 2 GPS points
#
# ...id:4502, must have at least 2 GPS points
#
# ...id:4503, must have at least 2 GPS points
#
# ...id:4505, must have at least 2 GPS points
#
# ...id:4506, must have at least 2 GPS points
#
# ...id:4507, must have at least 2 GPS points
#
# ...id:4509, must have at least 2 GPS points
#
# ...id:4519, must have at least 2 GPS points
#
# ...id:4526, must have at least 2 GPS points
#
# ...id:4529, must have at least 2 GPS points
#
# ...id:4532, must have at least 2 GPS points
#
# ...id:4541, must have at least 2 GPS points
#
# ...id:4542, must have at least 2 GPS points
#
# ...id:4543, must have at least 2 GPS points
#
# ...id:4544, must have at least 2 GPS points
#
# ...id:4554, must have at least 2 GPS points
#
# ...id:4558, must have at least 2 GPS points
#
# ...id:4559, must have at least 2 GPS points
#
# ...id:4560, must have at least 2 GPS points
#
# ...id:4562, must have at least 2 GPS points
#
# ...id:4565, must have at least 2 GPS points
#
# ...id:4567, must have at least 2 GPS points
#
# ...id:4568, must have at least 2 GPS points
#
# ...id:4569, must have at least 2 GPS points
#
# ...id:4570, must have at least 2 GPS points
#
# ...id:4571, must have at least 2 GPS points
#
# ...id:4572, must have at least 2 GPS points
#
# ...id:4589, must have at least 2 GPS points
#
# ...id:4590, must have at least 2 GPS points
#
# ...id:4591, must have at least 2 GPS points
#
# ...id:4595, must have at least 2 GPS points
#
# ...id:4599, must have at least 2 GPS points
#
# ...id:4605, must have at least 2 GPS points
#
# ...id:4608, must have at least 2 GPS points
#
# ...id:4616, must have at least 2 GPS points
#
# ...id:4617, must have at least 2 GPS points
#
# ...id:4619, must have at least 2 GPS points
#
# ...id:4622, must have at least 2 GPS points
#
# ...id:4627, must have at least 2 GPS points
#
# ...id:4629, must have at least 2 GPS points
#
# ...id:4630, must have at least 2 GPS points
#
# ...id:4631, must have at least 2 GPS points
#
# ...id:4632, must have at least 2 GPS points
#
# ...id:4634, must have at least 2 GPS points
#
# ...id:4635, must have at least 2 GPS points
#
# ...id:4636, must have at least 2 GPS points
#
# ...id:4638, must have at least 2 GPS points
#
# ...id:4641, must have at least 2 GPS points
#
# ...id:4642, must have at least 2 GPS points
#
# ...id:4646, must have at least 2 GPS points
#
# ...id:4647, must have at least 2 GPS points
#
# ...id:4650, must have at least 2 GPS points
#
# ...id:4653, must have at least 2 GPS points
#
# ...id:4656, must have at least 2 GPS points
# ...id:4658, must have at least 2 GPS points
#
# ...id:4659, must have at least 2 GPS points
#
# ...id:4660, must have at least 2 GPS points
#
# ...id:4662, must have at least 2 GPS points
#
# ...id:4665, must have at least 2 GPS points
#
# ...id:4666, must have at least 2 GPS points
#
# ...id:4667, must have at least 2 GPS points
#
# ...id:4668, must have at least 2 GPS points
#
# ...id:4669, must have at least 2 GPS points
#
# ...id:4673, must have at least 2 GPS points
#
# ...id:4681, must have at least 2 GPS points
#
# ...id:4685, must have at least 2 GPS points
#
# ...id:4689, must have at least 2 GPS points
#
# ...id:4691, must have at least 2 GPS points
#
# ...id:4697, must have at least 2 GPS points
#
# ...id:4701, must have at least 2 GPS points
#
# ...id:4708, must have at least 2 GPS points
#
# ...id:4709, must have at least 2 GPS points
#
# ...id:4710, must have at least 2 GPS points
#
# ...id:4711, must have at least 2 GPS points
#
# ...id:4712, must have at least 2 GPS points
#
# ...id:4713, must have at least 2 GPS points
#
# ...id:4714, must have at least 2 GPS points
#
# ...id:4715, must have at least 2 GPS points
#
# ...id:4716, must have at least 2 GPS points
#
# ...id:4717, must have at least 2 GPS points
#
# ...id:4718, must have at least 2 GPS points
#
# ...id:4719, must have at least 2 GPS points
#
# ...id:4720, must have at least 2 GPS points
#
# ...id:4721, must have at least 2 GPS points
#
# ...id:4722, must have at least 2 GPS points
#
# ...id:4723, must have at least 2 GPS points
#
# ...id:4724, must have at least 2 GPS points
#
# ...id:4728, must have at least 2 GPS points
#
# ...id:4730, must have at least 2 GPS points
#
# ...id:4733, must have at least 2 GPS points
#
# ...id:4734, must have at least 2 GPS points
#
# ...id:4739, must have at least 2 GPS points
#
# ...id:4743, must have at least 2 GPS points
#
# ...id:4745, must have at least 2 GPS points
#
# ...id:4747, must have at least 2 GPS points
#
# ...id:4748, must have at least 2 GPS points
#
# ...id:4749, must have at least 2 GPS points
#
# ...id:4751, must have at least 2 GPS points
#
# ...id:4752, must have at least 2 GPS points
#
# ...id:4755, must have at least 2 GPS points
#
# ...id:4758, must have at least 2 GPS points
#
# ...id:4769, must have at least 2 GPS points
#
# ...id:4770, must have at least 2 GPS points
#
# ...id:4771, must have at least 2 GPS points
#
# ...id:4773, must have at least 2 GPS points
#
# ...id:4782, must have at least 2 GPS points
#
# ...id:4784, must have at least 2 GPS points
#
# ...id:4785, must have at least 2 GPS points
#
# ...id:4786, must have at least 2 GPS points
#
# ...id:4787, must have at least 2 GPS points
#
# ...id:4788, must have at least 2 GPS points
#
# ...id:4789, must have at least 2 GPS points
#
# ...id:4790, must have at least 2 GPS points
#
# ...id:4791, must have at least 2 GPS points
#
# ...id:4793, must have at least 2 GPS points
#
# ...id:4794, must have at least 2 GPS points
#
# ...id:4795, must have at least 2 GPS points
#
# ...id:4796, must have at least 2 GPS points
#
# ...id:4797, must have at least 2 GPS points
#
# ...id:4798, must have at least 2 GPS points
#
# ...id:4799, must have at least 2 GPS points
#
# ...id:4800, must have at least 2 GPS points
#
# ...id:4802, must have at least 2 GPS points
#
# ...id:4803, must have at least 2 GPS points
#
# ...id:4804, must have at least 2 GPS points
#
# ...id:4805, must have at least 2 GPS points
#
# ...id:4806, must have at least 2 GPS points
#
# ...Reset index...
#
# ..Total Time: 8.053
# Create or update stop as True or False
# ...Creating stop features as True or False using 900 to time in seconds
# True     152603
# False     65050
# Name: stop, dtype: int64
#
# Total Time: 8.31 seconds
# -----------------------------------------------------
#
# ...setting mean to lat and lon...
# ...move segments will be dropped...
# ...get only segments stop...
# HBox(children=(IntProgress(value=0, max=285), HTML(value='')))
# (807/152603) 0% in 00:00:00.072 - estimated end in 00:00:13.694
# (8046/152603) 5% in 00:00:00.305 - estimated end in 00:00:05.483
# (15384/152603) 10% in 00:00:00.777 - estimated end in 00:00:06.938
# (23731/152603) 15% in 00:00:01.423 - estimated end in 00:00:07.728
# (31376/152603) 20% in 00:00:01.713 - estimated end in 00:00:06.620
# (38917/152603) 25% in 00:00:02.077 - estimated end in 00:00:06.068
# (46175/152603) 30% in 00:00:02.462 - estimated end in 00:00:05.675
# (53618/152603) 35% in 00:00:02.921 - estimated end in 00:00:05.392
# (61596/152603) 40% in 00:00:03.366 - estimated end in 00:00:04.974
# (69846/152603) 45% in 00:00:03.691 - estimated end in 00:00:04.373
# (76415/152603) 50% in 00:00:03.973 - estimated end in 00:00:03.961
# (84323/152603) 55% in 00:00:04.246 - estimated end in 00:00:03.438
# (91696/152603) 60% in 00:00:04.498 - estimated end in 00:00:02.988
# (99924/152603) 65% in 00:00:04.986 - estimated end in 00:00:02.628
# (107013/152603) 70% in 00:00:05.571 - estimated end in 00:00:02.373
# (114783/152603) 75% in 00:00:06.248 - estimated end in 00:00:02.058
# (122347/152603) 80% in 00:00:06.831 - estimated end in 00:00:01.689
# (129796/152603) 85% in 00:00:07.424 - estimated end in 00:00:01.304
# (137751/152603) 90% in 00:00:07.794 - estimated end in 00:00:00.840
# (145065/152603) 95% in 00:00:08.328 - estimated end in 00:00:00.432
# (152603/152603) 100% in 00:00:08.702 - estimated end in 00:00:00.000
#
# ...Dropping 217083 points...
# ...Shape_before: 217653
# ...Current shape: 570
# ...Compression time: 8.818 seconds
# -----------------------------------------------------

# %%
df_move
# Out:
#         segment_stop  id        lat         lon            datetime  \
# 562               13   1  40.008987  116.312734 2008-10-23 10:56:57
# 1368              13   1  39.990973  116.326094 2008-10-24 00:04:28
# 1575              17   1  39.978484  116.326845 2008-10-24 01:45:41
# 1847              17   1  39.980909  116.308171 2008-10-24 02:28:19
# 1938              21   1  39.981700  116.310196 2008-10-24 03:18:22
# 2646              21   1  39.982684  116.311197 2008-10-24 05:40:23
# 2667              25   1  39.981691  116.310004 2008-10-24 06:09:34
# 3039              25   1  39.979459  116.325806 2008-10-24 06:33:05
# 3089              27   1  40.013812  116.306483 2008-10-24 23:44:05
# 3924              27   1  39.997757  116.276764 2008-10-25 00:49:53
# 4035              33   1  40.004457  116.259773 2008-10-25 00:57:42
# 8376              33   1  39.988588  116.188416 2008-10-25 09:05:01
# 8377              34   1  39.988318  116.188511 2008-10-25 09:07:07
# 9082              34   1  39.992483  116.205002 2008-10-25 10:31:20
# 9258              39   1  40.002587  116.245163 2008-10-25 10:42:55
# 10168             39   1  40.013812  116.306622 2008-10-25 23:14:35
# 10172             41   1  40.014997  116.311526 2008-10-25 23:40:09
# 10745             41   1  40.065047  116.293166 2008-10-26 00:05:03
# 10746             42   1  40.070887  116.299294 2008-10-26 00:05:48
# 11571             42   1  40.069563  116.329480 2008-10-26 03:06:38
# 12435             46   1  39.976599  116.387014 2008-10-26 03:45:46
# 13123             46   1  39.976167  116.383538 2008-10-26 06:31:37
# 13124             47   1  39.975894  116.383520 2008-10-26 06:31:39
# 13833             47   1  39.977943  116.327093 2008-10-26 07:07:08
# 13842             50   1  39.977223  116.327262 2008-10-26 08:13:42
# 14235             50   1  39.998400  116.331349 2008-10-26 08:34:21
# 14236             51   1  39.998668  116.331412 2008-10-26 08:34:23
# 15689             51   1  40.013795  116.306502 2008-10-26 22:21:56
# 15693             54   1  40.013992  116.306535 2008-10-26 23:47:03
# 16150             54   1  40.002462  116.321671 2008-10-27 00:17:01
# ...              ...  ..        ...         ...                 ...
# 202335          4491   5  39.976594  116.336374 2009-01-16 14:09:03
# 202706          4491   5  39.974789  116.335120 2009-01-16 14:35:32
# 203620          4518   5  39.979956  116.340811 2009-01-16 15:25:19
# 203919          4518   5  39.976657  116.337568 2009-01-16 15:41:28
# 204597          4555   5  39.976091  116.336037 2009-01-16 18:19:11
# 206020          4555   5  39.976176  116.335944 2009-01-16 21:07:59
# 206021          4556   5  39.975994  116.335244 2009-01-16 21:08:26
# 206800          4556   5  39.977020  116.337718 2009-01-16 22:59:42
# 206801          4557   5  39.976807  116.337338 2009-01-16 22:59:44
# 207261          4557   5  39.975975  116.335851 2009-01-16 23:54:19
# 207721          4580   5  39.908299  116.590504 2009-01-17 08:51:28
# 209008          4580   5  39.903551  116.419657 2009-01-17 09:28:03
# 209009          4581   5  39.994270  116.326845 2009-01-17 10:33:47
# 209149          4581   5  39.995309  116.328426 2009-01-17 10:52:12
# 209156          4583   5  40.000044  116.326984 2009-01-19 10:15:53
# 209484          4583   5  40.009667  116.320185 2009-01-19 11:18:49
# 209570          4586   5  40.009433  116.322764 2009-01-19 12:59:38
# 210986          4586   5  39.999945  116.327439 2009-01-19 14:08:11
# 211541          4600   5  41.112310  121.151275 2009-01-22 01:01:12
# 212029          4600   5  41.118783  121.120368 2009-01-22 01:16:55
# 213952          4644   5  40.009650  116.323211 2009-02-22 05:53:10
# 214099          4644   5  40.003550  116.322399 2009-02-22 07:16:20
# 215172          4679   5  40.000630  116.321953 2009-02-22 11:27:58
# 215408          4679   5  40.010478  116.321621 2009-02-22 11:46:48
# 215984          4702   5  40.002918  116.321179 2009-02-27 15:25:04
# 216201          4702   5  40.008930  116.316370 2009-02-27 15:43:04
# 216653          4761   5  40.003937  116.322378 2009-03-12 09:31:37
# 216715          4761   5  40.009467  116.320154 2009-03-12 09:52:07
# 217072          4781   5  40.008938  116.322648 2009-03-14 05:32:32
# 217314          4781   5  39.990805  116.327712 2009-03-14 06:36:02
#
#         dist_to_prev  dist_to_next  dist_prev_to_next  tid_dist  time_to_prev  \
# 562              NaN     11.013568          26.512002         1           NaN
# 1368       16.068387     40.942759          56.717519         1           2.0
# 1575             NaN     14.366909          50.322414         1           NaN
# 1847       21.870376     51.683385          53.596809         1        1508.0
# 1938             NaN     20.642805          58.753841         1           NaN
# 2646        6.437367     73.921445          72.942149         1           5.0
# 2667             NaN     19.612423          51.388287         1           NaN
# 3039        5.697464     78.265156          83.404371         1           5.0
# 3089             NaN      7.587244        4358.356247         2           NaN
# 3924       12.807471    320.654991         327.200429         2           2.0
# 4035             NaN     10.710494          48.213454         2           NaN
# 8376        6.473607     31.094420          37.263285         2           5.0
# 8377             NaN      8.191995          29.368238         2           NaN
# 9082        0.278711     66.635675          66.824979         2           2.0
# 9258             NaN      9.581952        1887.327005         2           NaN
# 10168       5.917334    404.619469         404.277322         2           3.0
# 10172            NaN     20.556597          17.475348         2           NaN
# 10745      14.683896    832.837119         844.069232         2           1.0
# 10746            NaN     22.262448         853.339816         2           NaN
# 11571      21.312961     31.991527          53.142842         2           1.0
# 12435            NaN      4.280041        4535.822332         3           NaN
# 13123      10.732034     30.394938          41.115868         3           2.0
# 13124            NaN     12.151763          42.264467         3           NaN
# 13833       0.340831     33.430933          33.694844         3           2.0
# 13842            NaN      9.304585         373.345687         3           NaN
# 14235      18.801400     30.279586          48.825762         3           1.0
# 14236            NaN     22.957358          52.661448         3           NaN
# 15689       1.811438     78.491406          80.250827         3       39525.0
# 15693            NaN     16.790650          24.997219         3           NaN
# 16150       9.150153     54.380990          63.512925         3           5.0
# ...              ...           ...                ...       ...           ...
# 202335           NaN      6.411604          57.633581        18           NaN
# 202706      2.638475    112.687245         111.267406        18           5.0
# 203620           NaN     12.659169         126.204381        18           NaN
# 203919      1.905241    725.950377         724.385332        18           5.0
# 204597           NaN     14.584941         633.975490        18           NaN
# 206020      5.180888     62.986720          63.157675        18           2.0
# 206021           NaN      0.717040          62.414116        18           NaN
# 206800      5.480050     40.117135          34.637103        18           2.0
# 206801           NaN     15.973148          56.088907        18           NaN
# 207261      5.583204     72.044710          68.465215        18           3.0
# 207721           NaN     21.518733       20985.599732        19           NaN
# 209008      6.296828  12819.978690       12825.985712        19           3.0
# 209009           NaN      5.641112       12818.445704        20           NaN
# 209149      2.933556     47.286575          48.871189        20           5.0
# 209156           NaN     13.127912         462.740492        20           NaN
# 209484     14.650605     43.250854          31.859196        20           1.0
# 209570           NaN      7.549854          38.853750        20           NaN
# 210986      2.734828    188.595658         186.157032        20           5.0
# 211541           NaN      5.780594          45.316805        21           NaN
# 212029      2.859299     61.815163          60.241497        21           5.0
# 213952           NaN     26.477908          59.156210        23           NaN
# 214099     24.598991     33.481489          57.566291        23           5.0
# 215172           NaN     16.210203        1062.981283        23           NaN
# 215408      7.790798    453.726888         460.352157        23           5.0
# 215984           NaN     25.053212          23.671225        23           NaN
# 216201      1.223751    520.627318         521.086232        23           5.0
# 216653           NaN      6.449310         755.567765        24           NaN
# 216715      7.443679     32.663739          38.723962        24           5.0
# 217072           NaN     14.709253          73.928901        25           NaN
# 217314     14.694606     35.526076          49.736319        25           5.0
#
#         speed_to_prev  stop   lat_mean    lon_mean
# 562               NaN  True  40.013824  116.306535
# 1368         8.034193  True  40.013824  116.306535
# 1575              NaN  True  39.980124  116.310749
# 1847         0.014503  True  39.980124  116.310749
# 1938              NaN  True  39.979594  116.313750
# 2646         1.287473  True  39.979594  116.313750
# 2667              NaN  True  39.981541  116.310107
# 3039         1.139493  True  39.981541  116.310107
# 3089              NaN  True  39.996381  116.299268
# 3924         6.403736  True  39.996381  116.299268
# 4035              NaN  True  40.000154  116.165938
# 8376         1.294721  True  40.000154  116.165938
# 8377              NaN  True  39.992475  116.204994
# 9082         0.139355  True  39.992475  116.204994
# 9258              NaN  True  39.996362  116.286608
# 10168        1.972445  True  39.996362  116.286608
# 10172             NaN  True  40.031189  116.313866
# 10745       14.683896  True  40.031189  116.313866
# 10746             NaN  True  40.069755  116.331024
# 11571       21.312961  True  40.069755  116.331024
# 12435             NaN  True  39.977652  116.384150
# 13123        5.366017  True  39.977652  116.384150
# 13124             NaN  True  39.975650  116.385649
# 13833        0.170416  True  39.975650  116.385649
# 13842             NaN  True  39.975372  116.333898
# 14235       18.801400  True  39.975372  116.333898
# 14236             NaN  True  40.013805  116.306497
# 15689        0.000046  True  40.013805  116.306497
# 15693             NaN  True  40.014950  116.311317
# 16150        1.830031  True  40.014950  116.311317
# ...               ...   ...        ...         ...
# 202335            NaN  True  39.975697  116.336035
# 202706       0.527695  True  39.975697  116.336035
# 203620            NaN  True  39.977667  116.338788
# 203919       0.381048  True  39.977667  116.338788
# 204597            NaN  True  39.976178  116.336199
# 206020       2.590444  True  39.976178  116.336199
# 206021            NaN  True  39.976033  116.336186
# 206800       2.740025  True  39.976033  116.336186
# 206801            NaN  True  39.976201  116.336258
# 207261       1.861068  True  39.976201  116.336258
# 207721            NaN  True  39.906999  116.457662
# 209008       2.098943  True  39.906999  116.457662
# 209009            NaN  True  39.995065  116.326601
# 209149       0.586711  True  39.995065  116.326601
# 209156            NaN  True  40.009451  116.320408
# 209484      14.650605  True  40.009451  116.320408
# 209570            NaN  True  40.009390  116.322575
# 210986       0.546966  True  40.009390  116.322575
# 211541            NaN  True  41.113731  121.141849
# 212029       0.571860  True  41.113731  121.141849
# 213952            NaN  True  40.005382  116.322092
# 214099       4.919798  True  40.005382  116.322092
# 215172            NaN  True  40.010956  116.321853
# 215408       1.558160  True  40.010956  116.321853
# 215984            NaN  True  40.008942  116.316356
# 216201       0.244750  True  40.008942  116.316356
# 216653            NaN  True  40.009501  116.320438
# 216715       1.488736  True  40.009501  116.320438
# 217072            NaN  True  40.004262  116.324129
# 217314       2.938921  True  40.004262  116.324129
#
# [570 rows x 14 columns]
