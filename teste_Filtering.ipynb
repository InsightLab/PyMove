# %%
import pandas as pd
import numpy as np
from pymove.core.MoveDataFrame import MoveDataFrame

# %%
from pymove.preprocessing import filter

# %%
from pymove.utils import transformations

# %%
df = pd.read_csv('examples/geolife_sample.csv', parse_dates=['datetime'])
df.head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217653 entries, 0 to 217652
# Data columns (total 4 columns):
# lat         217653 non-null float64
# lon         217653 non-null float64
# datetime    217653 non-null datetime64[ns]
# id          217653 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 6.6 MB

# %%
df_move = MoveDataFrame(df, latitude="lat", longitude="lon", datetime="datetime")

# %%
bbox = (22.147577, 113.54884299999999, 41.132062, 121.156224)
bbox
# Out:
# (22.147577, 113.54884299999999, 41.132062, 121.156224)

# %%
filter.filter_bbox(df_move, bbox, filter_out = True)
# Out:
# Empty DataFrame
# Columns: [lat, lon, datetime, id]
# Index: []

# %%
filter.filter_by_datetime(df_move,"2009-03-19 05:45:37", "2009-03-19 05:46:17")
# Out:
#               lat         lon            datetime  id
# 217644  40.000128  116.327171 2009-03-19 05:45:42   5
# 217645  40.000069  116.327179 2009-03-19 05:45:47   5
# 217646  40.000001  116.327219 2009-03-19 05:45:52   5
# 217647  39.999919  116.327211 2009-03-19 05:45:57   5
# 217648  39.999896  116.327290 2009-03-19 05:46:02   5
# 217649  39.999899  116.327352 2009-03-19 05:46:07   5
# 217650  39.999945  116.327394 2009-03-19 05:46:12   5
# 217651  40.000015  116.327433 2009-03-19 05:46:17   5

# %%
filter.filter_by_label(df_move, 116.327219, "lon").head()
# Out:
#              lat         lon            datetime  id
# 3066   39.979160  116.327219 2008-10-24 06:34:27   1
# 13911  39.975424  116.327219 2008-10-26 08:18:06   1
# 16396  39.980411  116.327219 2008-10-27 00:30:47   1
# 33935  39.975832  116.327219 2008-11-05 11:04:04   1
# 41636  39.976990  116.327219 2008-11-07 10:34:41   1

# %%
teste = filter.filter_by_label(df_move, "2008-10-24 04:12:30" , "datetime")
type(teste)
# Out:
# pandas.core.frame.DataFrame

# %%
filter.filter_by_label(df_move, "2008-10-24 04:12:30" , "datetime", filter_out=True).head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
filter.filter_by_id(df_move, 5).head()
# Out:
#               lat         lon            datetime  id
# 108607  40.004155  116.321337 2008-10-24 04:12:30   5
# 108608  40.003834  116.321462 2008-10-24 04:12:35   5
# 108609  40.003783  116.321431 2008-10-24 04:12:40   5
# 108610  40.003690  116.321429 2008-10-24 04:12:45   5
# 108611  40.003589  116.321427 2008-10-24 04:12:50   5

#
#    time_to_prev  speed_to_prev  dist_to_next  dist_prev_to_next
# 0           NaN            NaN     13.690153                NaN
# 1           1.0      13.690153      7.403788          20.223428
# 2           5.0       1.480758      1.821083           5.888579
# 3           5.0       0.364217      2.889671           1.873356
# 4           5.0       0.577934     66.555997          68.727260

# %%
filter.clean_NaN_values(df_move)

# %%
filter.clean_gps_jumps_by_distance(df_move)
# Out:
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217649/217649) 100% in 00:00:00.079 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.08477354049682617
#
# Cleaning gps jumps by distance to jump_coefficient 3.0...
#
# ...Filtring jumps
#
# ...Dropping 383 rows of gps points
#
# ...Rows before: 217649, Rows after:217266, Sum drop:383
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217266/217266) 100% in 00:00:00.088 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.0947108268737793
#
# Cleaning gps jumps by distance to jump_coefficient 3.0...
#
# ...Filtring jumps
#
# ...Dropping 3 rows of gps points
#
# ...Rows before: 217266, Rows after:217263, Sum drop:386
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217263/217263) 100% in 00:00:00.094 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09973359107971191
#
# Cleaning gps jumps by distance to jump_coefficient 3.0...
#
# ...Filtring jumps
#
# 386 GPS points were dropped

# %%
filter.clean_gps_nearby_points_by_distances(df_move)
# Out:
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217263/217263) 100% in 00:00:00.086 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09175229072570801
#
# Cleaning gps points from radius of 10.0 meters
#
# ...There are 137585 gps points to drop
#
# ...Dropping 137585 gps points
#
# ...Rows before: 217263, Rows after:79678
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (79678/79678) 100% in 00:00:00.023 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.027926206588745117
#
# Cleaning gps points from radius of 10.0 meters
#
# ...There are 616 gps points to drop
#
# ...Dropping 616 gps points
#
# ...Rows before: 79678, Rows after:79062
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (79062/79062) 100% in 00:00:00.028 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.0359044075012207
#
# Cleaning gps points from radius of 10.0 meters
#
# ...There are 44 gps points to drop
#
# ...Dropping 44 gps points
#
# ...Rows before: 79062, Rows after:79018
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (79018/79018) 100% in 00:00:00.025 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.029918193817138672
#
# Cleaning gps points from radius of 10.0 meters
#
# ...There are 0 gps points to drop

# %%
filter.clean_gps_nearby_points_by_speed(df_move)
# Out:
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (79018/79018) 100% in 00:00:00.082 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.088
#
# Cleaning gps points using 0.0 speed radius
#
# ...There are 0 gps points to drop

# %%
filter.clean_gps_speed_max_radius(df_move)
# Out:
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (79018/79018) 100% in 00:00:00.063 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.068
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 123 gps points with speed_max > 50.0
#
# ...Dropping 123 rows of jumps by speed max
#
# ...Rows before: 79018, Rows after:78895
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78895/78895) 100% in 00:00:00.063 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.069
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 43 gps points with speed_max > 50.0
#
# ...Dropping 43 rows of jumps by speed max
#
# ...Rows before: 78895, Rows after:78852
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78852/78852) 100% in 00:00:00.061 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.066
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 21 gps points with speed_max > 50.0
#
# ...Dropping 21 rows of jumps by speed max
#
# ...Rows before: 78852, Rows after:78831
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78831/78831) 100% in 00:00:00.056 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.061
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 7 gps points with speed_max > 50.0
#
# ...Dropping 7 rows of jumps by speed max
#
# ...Rows before: 78831, Rows after:78824
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78824/78824) 100% in 00:00:00.058 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.063
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 5 gps points with speed_max > 50.0
#
# ...Dropping 5 rows of jumps by speed max
#
# ...Rows before: 78824, Rows after:78819
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78819/78819) 100% in 00:00:00.062 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.067
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 3 gps points with speed_max > 50.0
#
# ...Dropping 3 rows of jumps by speed max
#
# ...Rows before: 78819, Rows after:78816
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78816/78816) 100% in 00:00:00.058 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.064
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 3 gps points with speed_max > 50.0
#
# ...Dropping 3 rows of jumps by speed max
#
# ...Rows before: 78816, Rows after:78813
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78813/78813) 100% in 00:00:00.061 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.072
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 2 gps points with speed_max > 50.0
#
# ...Dropping 2 rows of jumps by speed max
#
# ...Rows before: 78813, Rows after:78811
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78811/78811) 100% in 00:00:00.065 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.071
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 2 gps points with speed_max > 50.0
#
# ...Dropping 2 rows of jumps by speed max
#
# ...Rows before: 78811, Rows after:78809
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78809/78809) 100% in 00:00:00.065 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.071
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 2 gps points with speed_max > 50.0
#
# ...Dropping 2 rows of jumps by speed max
#
# ...Rows before: 78809, Rows after:78807
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78807/78807) 100% in 00:00:00.066 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.072
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 2 gps points with speed_max > 50.0
#
# ...Dropping 2 rows of jumps by speed max
#
# ...Rows before: 78807, Rows after:78805
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78805/78805) 100% in 00:00:00.059 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.064
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 2 gps points with speed_max > 50.0
#
# ...Dropping 2 rows of jumps by speed max
#
# ...Rows before: 78805, Rows after:78803
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78803/78803) 100% in 00:00:00.062 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.068
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 1 gps points with speed_max > 50.0
#
# ...Dropping 1 rows of jumps by speed max
#
# ...Rows before: 78803, Rows after:78802
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to a higher peformance
#
# (78802/78802) 100% in 00:00:00.061 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.067
#
# Clean gps points with speed max > 50.0 meters by seconds
# ...There 0 gps points with speed_max > 50.0

# %%
filter.clean_trajectories_with_few_points(df_move)
# Out:
# ...There are 25 ids with few points
#
# ...Tids before drop: 598
#
# ...Tids after drop: 573
#
# ...Shape - before drop: (78802, 10) - after drop: (78777, 10)
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by tid and datetime to increase performance
#
# ...Set tid as index to a higher peformance
#
# (78/78777) 0% in 00:00:00.090 - estimated end in 00:01:31.572
# (15761/78777) 20% in 00:00:00.120 - estimated end in 00:00:00.482
# (31862/78777) 40% in 00:00:00.152 - estimated end in 00:00:00.224
# (47444/78777) 60% in 00:00:00.167 - estimated end in 00:00:00.110
# (63120/78777) 80% in 00:00:00.194 - estimated end in 00:00:00.048
# (78777/78777) 100% in 00:00:00.236 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.241

# %%
filter.clean_trajectories_short_and_few_points_(df_move)
# Out:
# Remove short trajectories...
#
# ...There are 0 ids with few points
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by tid and datetime to increase performance
#
# ...Set tid as index to a higher peformance
#
# (78/78679) 0% in 00:00:00.065 - estimated end in 00:01:06.331
# (15759/78679) 20% in 00:00:00.084 - estimated end in 00:00:00.338
# (31829/78679) 40% in 00:00:00.100 - estimated end in 00:00:00.148
# (47399/78679) 60% in 00:00:00.114 - estimated end in 00:00:00.075
# (63065/78679) 80% in 00:00:00.143 - estimated end in 00:00:00.035
# (78679/78679) 100% in 00:00:00.181 - estimated end in 00:00:00.000
# ...Reset index...
#
# ..Total Time: 0.185
#
# ...Dropping unnecessary trajectories...
#
# ...short trajectories and trajectories with a minimum distance (546): 100
#
# ...There are 0 tid do drop
