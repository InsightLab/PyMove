# %%
from pymove import stay_point_detection

# %%
import pandas as pd
from pymove import MoveDataFrame

# %%
df = pd.read_csv('examples/geolife_sample.csv', parse_dates=['datetime'])
df.head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
df_move = MoveDataFrame(df, latitude="lat", longitude="lon", datetime="datetime")

# %%
stay_point_detection.create_update_move_and_stop_by_radius(df_move)
# Out:
# Creating or updating features MOVE and STOPS...
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217653/217653) 100% in 00:00:00.090 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09773993492126465
#
# ....There are 14691 stops to this parameters

# %%
df_move
# Out:
#         id        lat         lon            datetime  dist_to_prev  \
# 0        1  39.984094  116.319236 2008-10-23 05:53:05           NaN
# 1        1  39.984198  116.319322 2008-10-23 05:53:06     13.690153
# 2        1  39.984224  116.319402 2008-10-23 05:53:11      7.403788
# 3        1  39.984211  116.319389 2008-10-23 05:53:16      1.821083
# 4        1  39.984217  116.319422 2008-10-23 05:53:21      2.889671
# 5        1  39.984710  116.319865 2008-10-23 05:53:23     66.555997
# 6        1  39.984674  116.319810 2008-10-23 05:53:28      6.162987
# 7        1  39.984623  116.319773 2008-10-23 05:53:33      6.488225
# 8        1  39.984606  116.319732 2008-10-23 05:53:38      3.971848
# 9        1  39.984555  116.319728 2008-10-23 05:53:43      5.681172
# 10       1  39.984579  116.319769 2008-10-23 05:53:48      4.395924
# 11       1  39.984579  116.319769 2008-10-23 05:53:51      0.000000
# 12       1  39.984577  116.319766 2008-10-23 05:53:53      0.338804
# ...

# %%
stay_point_detection.create_or_update_move_stop_by_dist_time(df_move)
# Out:
# Split trajectories by max distance between adjacent points: 30
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217653/217653) 100% in 00:00:00.089 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09673905372619629
# ...setting id as index
# (217653/217653) 100% in 00:00:00.094 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.10 seconds
# ------------------------------------------
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by segment_stop and datetime to increase performance
#
# ...Set segment_stop as index to a higher peformance
#
# (5/217653) 0% in 00:00:00.185 - estimated end in 02:14:13.658
# (43973/217653) 20% in 00:00:00.235 - estimated end in 00:00:00.931
# (88533/217653) 40% in 00:00:00.286 - estimated end in 00:00:00.418
# ...

# %%
df_move
# Out:
#         segment_stop  id        lat         lon            datetime  \
# 0                  1   1  39.984094  116.319236 2008-10-23 05:53:05
# 1                  1   1  39.984198  116.319322 2008-10-23 05:53:06
# 2                  1   1  39.984224  116.319402 2008-10-23 05:53:11
# 3                  1   1  39.984211  116.319389 2008-10-23 05:53:16
# 4                  1   1  39.984217  116.319422 2008-10-23 05:53:21
# 5                  2   1  39.984710  116.319865 2008-10-23 05:53:23
# 6                  2   1  39.984674  116.319810 2008-10-23 05:53:28
# 7                  2   1  39.984623  116.319773 2008-10-23 05:53:33
# 8                  2   1  39.984606  116.319732 2008-10-23 05:53:38
# 9                  2   1  39.984555  116.319728 2008-10-23 05:53:43
# 10                 2   1  39.984579  116.319769 2008-10-23 05:53:48
# 11                 2   1  39.984579  116.319769 2008-10-23 05:53:51
# 12                 2   1  39.984577  116.319766 2008-10-23 05:53:53
# ...

# %%
df_move.stop.unique()
# Out:
# array([False,  True])

# %%
df_move['stop'].value_counts()
# Out:
# True     152603
# False     65050
# Name: stop, dtype: int64
