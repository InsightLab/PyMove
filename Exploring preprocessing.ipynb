# %% [markdown]
# ## Preprocessing trajectory data

# %% [markdown]
# Data preprocessing is a set of activities performed to prepare data for future analysis and data mining activities.

# %% [markdown]
# ## Load data from file

# %% [markdown]
# The dataset used in this tutorial is GeoLife GPS Trajectories. Available in https://www.microsoft.com/en-us/download/details.aspx?id=52367

# %%
import pandas as pd
import numpy as np
from pymove import MoveDataFrame

# %%
df = pd.read_csv('examples/geolife_sample.csv', parse_dates=['datetime'])
df.head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
df_move = MoveDataFrame(df, latitude="lat", longitude="lon", datetime="datetime")

# %%
df_move.show_trajectories_info()

# %% [markdown]
# ## Filtering

# %% [markdown]
# The filters module provides functions to perform different types of data filtering.

# %% [markdown]
# Importing the module:

# %%
from pymove import filters

# %% [markdown]
# A bounding box (usually shortened to bbox) is an area defined by two longitudes and two latitudes. The function by_bbox, filters points of the trajectories according to a especified bounding box.

# %%
bbox = (22.147577, 113.54884299999999, 41.132062, 121.156224)
filt_df = filters.by_bbox(df_move, bbox)
filt_df.head()

# %% [markdown]
# by_datetime function filters point trajectories according to the time specified by the parameters: start_datetime and end_datetime.

# %%
filters.by_datetime(df_move,start_datetime = "2009-03-19 05:45:37", end_datetime = "2009-03-19 05:46:17")

# %% [markdown]
# by label function filters trajectories points according to specified value and column label, set by value and label_name respectively.

# %%
filters.by_label(df_move, value = 116.327219, label_name = "lon").head()

# %% [markdown]
# by_id function filters trajectories points according to especified trajectory id.

# %%
filters.by_id(df_move, id_=5).head()

# %% [markdown]
# A tid is the result of concatenation between the id and date of a trajectory.
# The by_tid function filters trajectory points according to the tid specified by the tid_ parameter.

# %%
df_move.generate_tid_based_on_id_datatime()
filters.by_tid(df_move, "12008102305").head()

# %% [markdown]
# outliers function filters trajectories points that are outliers.

# %%
outliers_points = filters.outliers(df_move)
outiliers_points.head()

# %% [markdown]
# clen_duplicates function removes the duplicate rows of the Dataframe, optionally only certaind columns can be consider.

# %%
filters.clean_duplicates(df_move)

# %% [markdown]
# clean_consecutive_duplicates function removes consecutives duplicate rows of the Dataframe. Optionally only certaind columns can be consider, this is defined by the parameter subset, in this example only the lat column is considered.

# %%
filtered_df = filters.clean_consecutive_duplicates(df_move, subset = ["lat"])
len(filtered_df)

# %% [markdown]
# clean_nan_values function removes missing values from the dataframe.

# %%
filters.clean_nan_values(df_move)
len(df_move)

# %% [markdown]
# clean_gps_jumps_by_distance function removes from the dataframe the trajectories points that are outliers.

# %%
filters.clean_gps_jumps_by_distance(df_move)

# %% [markdown]
# clean_gps_nearby_points_by_distances function removes points from the trajectories when the distance between them and the point before is smaller than the parameter radius_area.

# %%
filters.clean_gps_nearby_points_by_distances(df_move, radius_area = 10)

# %% [markdown]
# clean_gps_nearby_points_by_speed function removes points from the trajectories when the speed of travel between them
# and the point before is smaller than the value set by the parameter speed_radius.

# %%
filters.clean_gps_nearby_points_by_speed(df_move, speed_radius=40.0)

# %% [markdown]
# clean_gps_speed_max_radius function recursively removes trajectories points with speed higher than the value especifeid by the user.
#     Given any point p of the trajectory, the point will be removed if one of the following happens:
#     if the travel speed from the point before p to p is greater than the  max value of speed between adjacent
#     points set by the user. Or the travel speed between point p and the next point is greater than the value set by
#     the user. When the clening is done, the function will update the time and distance features in the dataframe and
#     will call itself again.
#     The function will finish processing when it can no longer find points disrespecting the limit of speed.

# %%
filters.clean_gps_speed_max_radius(df_move)

# %% [markdown]
# clean_trajectories_with_few_points function removes from the given dataframe, trajectories with fewer points than was specified by the parameter min_points_per_trajectory.

# %%
filters.clean_trajectories_with_few_points(df_move)

# %% [markdown]
# ## Segmantation

# %% [markdown]
# The segmentation module are used to segment trajectories based on different parameters.

# %% [markdown]
# Importing the module:

# %%
from pymove import segmentation

# %% [markdown]
# bbox_split function splits the bounding box in grids of the same size. The number of grids is defined by the parameter number_grids.

# %%
bbox = (22.147577, 113.54884299999999, 41.132062, 121.156224)
segmentation.bbox_split(bbox, number_grids=4)

# %% [markdown]
# by_dist_time_speed functions segments the trajectories into clusters based on distance, time and speed. The distance, time and speed limits by the parameters by max_dist_between_adj_points, max_time_between_adj_points, max_speed_between_adj_points respectively. The column tid_part is added, it indicates the segment which the point belongs to.

# %%
segmentation.by_dist_time_speed(df_move, max_dist_between_adj_points=5000, 
                                max_time_between_adj_points=800,max_speed_between_adj_points=60.0)
df_move.head()

# %% [markdown]
# by_speed function segments the trajectories into clusters based on speed. The speed limit is defined by the parameter max_speed_between_adj_points. The column tid_seed is added, it indicates the segment which the point belongs to.

# %%
segmentation.by_speed(df_move, max_speed_between_adj_points=70.0)
df_move.head()

# %% [markdown]
# by_time function segments the trajectories into clusters based on time. The time limit is defined by the parameter max_time_between_adj_points. The column tid_time is added, it indicates the segment which the point belongs to.

# %%
segmentation.by_time(df_move, max_time_between_adj_points = 1000)
df_move.head()

# %% [markdown]
# segment_traj_by_max_dist function segments the trajectories into clusters based on distance. The distance limit is defined by the parameter max_dist_between_adj_points. The column tid_dist is added, it indicates the segment which the point belongs to.

# %%
segmentation.segment_traj_by_max_dist(df_move, max_dist_between_adj_points = 4000)
df_move.head()
# Out:
# Split trajectories by max distance between adjacent points: 4000
# ...setting id as index
# C:\Users\Arina\Desktop\PyMove\pymove\preprocessing\segmentation.py:398: RuntimeWarning: invalid value encountered in greater
#   dist = (df_.at[idx, DIST_TO_PREV] > max_dist_between_adj_points)
# (217653/217653) 100% in 00:00:00.018 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.02 seconds
# ------------------------------------------
#    id        lat         lon            datetime  dist_to_prev  dist_to_next  \
# 0   1  39.984094  116.319236 2008-10-23 05:53:05           NaN     13.690153
# 1   1  39.984198  116.319322 2008-10-23 05:53:06     13.690153      7.403788
# 2   1  39.984224  116.319402 2008-10-23 05:53:11      7.403788      1.821083
# 3   1  39.984211  116.319389 2008-10-23 05:53:16      1.821083      2.889671
# 4   1  39.984217  116.319422 2008-10-23 05:53:21      2.889671     66.555997
#
#    dist_prev_to_next situation  tid_dist
# 0                NaN       nan         1
# 1          20.223428      move         1
# 2           5.888579      move         1
# 3           1.873356      stop         1
# 4          68.727260      move         1

# %% [markdown]
# ## Stay point detection

# %% [markdown]
# A stay point is location where a moving object has stayed for a while within a certain distance threshold. A stay point could stand different places such: a restaurant, a school, a work place.

# %% [markdown]
# Importing the module:

# %%
from pymove import stay_point_detection

# %% [markdown]
# stay_point_detection function converts the time data into a cyclical format. The columns hour_sin and hour_cos are added to the dataframe.

# %%
stay_point_detection.create_update_datetime_in_format_cyclical(df_move)
# Out:
# Encoding cyclical continuous features - 24-hour time
# ...hour_sin and  hour_cos features were created...

# %%
df_move.head()
# Out:
#          lat         lon            datetime  id  hour_sin  hour_cos
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  0.979084  0.203456
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  0.979084  0.203456
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  0.979084  0.203456
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  0.979084  0.203456
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  0.979084  0.203456

# %% [markdown]
# create_or_update_move_stop_by_dist_time function creates or updates the stay points of the trajectories, based on distance and time metrics. The column segment_stop is added to the dataframe, it indicates the trajectory segment which the point belongs to. The column stop is also added, it indicates is the point represents a stop, a place where the object was stationary.

# %%
stay_point_detection.create_or_update_move_stop_by_dist_time(df_move, dist_radius=40, time_radius=1000)
# Out:
# Split trajectories by max distance between adjacent points: 40
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217653/217653) 100% in 00:00:00.088 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09474706649780273
# ...setting id as index
# C:\Users\Arina\Desktop\PyMove\pymove\preprocessing\segmentation.py:398: RuntimeWarning: invalid value encountered in greater
#   dist = (df_.at[idx, DIST_TO_PREV] > max_dist_between_adj_points)
# (217653/217653) 100% in 00:00:00.064 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.07 seconds
# ------------------------------------------
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by segment_stop and datetime to increase performance
#
# ...Set segment_stop as index to a higher peformance
#
# (5/217653) 0% in 00:00:00.176 - estimated end in 02:08:04.202
# (43995/217653) 20% in 00:00:00.228 - estimated end in 00:00:00.901
# (88581/217653) 40% in 00:00:00.276 - estimated end in 00:00:00.403
# (130800/217653) 60% in 00:00:00.338 - estimated end in 00:00:00.224
# (174825/217653) 80% in 00:00:00.481 - estimated end in 00:00:00.118
# ...Reset index...
#
# ..Total Time: 0.584
# Create or update stop as True or False
# ...Creating stop features as True or False using 1000 to time in seconds
# True     157738
# False     59915
# Name: stop, dtype: int64
#
# Total Time: 1.02 seconds
# -----------------------------------------------------

# %%
df_move.head()
# Out:
#    segment_stop  id        lat         lon            datetime  hour_sin  \
# 0             1   1  39.984094  116.319236 2008-10-23 05:53:05  0.979084
# 1             1   1  39.984198  116.319322 2008-10-23 05:53:06  0.979084
# 2             1   1  39.984224  116.319402 2008-10-23 05:53:11  0.979084
# 3             1   1  39.984211  116.319389 2008-10-23 05:53:16  0.979084
# 4             1   1  39.984217  116.319422 2008-10-23 05:53:21  0.979084
#
#    hour_cos  dist_to_prev  dist_to_next  dist_prev_to_next  time_to_prev  \
# 0  0.203456           NaN     13.690153                NaN           NaN
# 1  0.203456     13.690153      7.403788          20.223428           1.0
# 2  0.203456      7.403788      1.821083           5.888579           5.0
# 3  0.203456      1.821083      2.889671           1.873356           5.0
# 4  0.203456      2.889671     66.555997          68.727260           5.0
#
#    speed_to_prev   stop
# 0            NaN  False
# 1      13.690153  False
# 2       1.480758  False
# 3       0.364217  False
# 4       0.577934  False

# %% [markdown]
# create_update_move_and_stop_by_radius function creates or updates the stay points of the trajectories, based on distance. The column segment_stop is added to the dataframe, it indicates the trajectory segment which the point belongs to. The column situation is also added, it indicates is the point represents a stop point or a moving point.

# %%
stay_point_detection.create_update_move_and_stop_by_radius(df_move, radius=2)
# Out:
# Creating or updating features MOVE and STOPS...
#
#
# Creating or updating distance features in meters...
#
# ...Sorting by id and datetime to increase performance
#
# ...Set id as index to increase attribution performance
#
# (217653/217653) 100% in 00:00:00.092 - estimated end in 00:00:00.000
# ...Reset index
#
# ..Total Time: 0.09885811805725098
#
# ....There are 58981 stops to this parameters

# %%
df_move.head()
# Out:
#    segment_stop  id        lat         lon            datetime  hour_sin  \
# 0             1   1  39.984094  116.319236 2008-10-23 05:53:05  0.979084
# 1             1   1  39.984198  116.319322 2008-10-23 05:53:06  0.979084
# 2             1   1  39.984224  116.319402 2008-10-23 05:53:11  0.979084
# 3             1   1  39.984211  116.319389 2008-10-23 05:53:16  0.979084
# 4             1   1  39.984217  116.319422 2008-10-23 05:53:21  0.979084
#
#    hour_cos  dist_to_prev  dist_to_next  dist_prev_to_next  time_to_prev  \
# 0  0.203456           NaN     13.690153                NaN           NaN
# 1  0.203456     13.690153      7.403788          20.223428           1.0
# 2  0.203456      7.403788      1.821083           5.888579           5.0
# 3  0.203456      1.821083      2.889671           1.873356           5.0
# 4  0.203456      2.889671     66.555997          68.727260           5.0
#
#    speed_to_prev   stop situation
# 0            NaN  False       nan
# 1      13.690153  False      move
# 2       1.480758  False      move
# 3       0.364217  False      stop
# 4       0.577934  False      move

# %% [markdown]
# ## Compression

# %% [markdown]
# Importing the module:

# %%
from pymove import compression

# %% [markdown]
# The function below is used to reduce the size of the trajectory, the stop points are used to make the compression.

# %%
compression.compress_segment_stop_to_point(df_move)
# Out:
# Split trajectories by max distance between adjacent points: 30
# ...setting id as index
# C:\Users\Arina\Desktop\PyMove\pymove\preprocessing\segmentation.py:398: RuntimeWarning: invalid value encountered in greater
#   dist = (df_.at[idx, DIST_TO_PREV] > max_dist_between_adj_points)
# (217653/217653) 100% in 00:00:00.079 - estimated end in 00:00:00.000
# ... Reseting index
#
# Total Time: 0.08 seconds
# ------------------------------------------
#
#
# Creating or updating distance, time and speed features in meters by seconds
#
# ...Sorting by segment_stop and datetime to increase performance
#
# ...Set segment_stop as index to a higher peformance
#
# (5/217653) 0% in 00:00:00.159 - estimated end in 01:55:48.248
# (43973/217653) 20% in 00:00:00.213 - estimated end in 00:00:00.843
# (88533/217653) 40% in 00:00:00.261 - estimated end in 00:00:00.381
# (130666/217653) 60% in 00:00:00.326 - estimated end in 00:00:00.217
# (174240/217653) 80% in 00:00:00.533 - estimated end in 00:00:00.132
# ...Reset index...
#
# ..Total Time: 0.657
# Create or update stop as True or False
# ...Creating stop features as True or False using 900 to time in seconds
# True     152603
# False     65050
# Name: stop, dtype: int64
#
# Total Time: 0.86 seconds
# -----------------------------------------------------
#
# ...setting mean to lat and lon...
# ...move segments will be dropped...
# ...get only segments stop...
# HBox(children=(IntProgress(value=0, max=285), HTML(value='')))
# (807/152603) 0% in 00:00:00.086 - estimated end in 00:00:16.321
# (8046/152603) 5% in 00:00:00.237 - estimated end in 00:00:04.265
# (15384/152603) 10% in 00:00:00.537 - estimated end in 00:00:04.795
# (23731/152603) 15% in 00:00:01.050 - estimated end in 00:00:05.705
# (31376/152603) 20% in 00:00:01.219 - estimated end in 00:00:04.713
# (38917/152603) 25% in 00:00:01.440 - estimated end in 00:00:04.207
# (46175/152603) 30% in 00:00:01.683 - estimated end in 00:00:03.880
# (53618/152603) 35% in 00:00:01.999 - estimated end in 00:00:03.692
# (61596/152603) 40% in 00:00:02.260 - estimated end in 00:00:03.339
# (69846/152603) 45% in 00:00:02.591 - estimated end in 00:00:03.070
# (76415/152603) 50% in 00:00:02.799 - estimated end in 00:00:02.791
# (84323/152603) 55% in 00:00:03.022 - estimated end in 00:00:02.447
# (91696/152603) 60% in 00:00:03.220 - estimated end in 00:00:02.138
# (99924/152603) 65% in 00:00:03.616 - estimated end in 00:00:01.906
# (107013/152603) 70% in 00:00:04.067 - estimated end in 00:00:01.732
# (114783/152603) 75% in 00:00:04.646 - estimated end in 00:00:01.531
# (122347/152603) 80% in 00:00:05.177 - estimated end in 00:00:01.280
# (129796/152603) 85% in 00:00:05.734 - estimated end in 00:00:01.007
# (137751/152603) 90% in 00:00:06.076 - estimated end in 00:00:00.655
# (145065/152603) 95% in 00:00:06.575 - estimated end in 00:00:00.341
# (152603/152603) 100% in 00:00:06.895 - estimated end in 00:00:00.000
#
# ...Dropping 217083 points...
# ...Shape_before: 217653
# ...Current shape: 570
# ...Compression time: 7.009 seconds
# -----------------------------------------------------

# %%
df_move
# Out:
#         segment_stop  id        lat         lon            datetime  \
# 562               13   1  40.008987  116.312734 2008-10-23 10:56:57
# 1368              13   1  39.990973  116.326094 2008-10-24 00:04:28
# 1575              17   1  39.978484  116.326845 2008-10-24 01:45:41
# 1847              17   1  39.980909  116.308171 2008-10-24 02:28:19
# 1938              21   1  39.981700  116.310196 2008-10-24 03:18:22
# 2646              21   1  39.982684  116.311197 2008-10-24 05:40:23
# 2667              25   1  39.981691  116.310004 2008-10-24 06:09:34
# 3039              25   1  39.979459  116.325806 2008-10-24 06:33:05
# 3089              27   1  40.013812  116.306483 2008-10-24 23:44:05
# 3924              27   1  39.997757  116.276764 2008-10-25 00:49:53
# 4035              33   1  40.004457  116.259773 2008-10-25 00:57:42
# 8376              33   1  39.988588  116.188416 2008-10-25 09:05:01
# 8377              34   1  39.988318  116.188511 2008-10-25 09:07:07
# 9082              34   1  39.992483  116.205002 2008-10-25 10:31:20
# 9258              39   1  40.002587  116.245163 2008-10-25 10:42:55
# 10168             39   1  40.013812  116.306622 2008-10-25 23:14:35
# 10172             41   1  40.014997  116.311526 2008-10-25 23:40:09
# 10745             41   1  40.065047  116.293166 2008-10-26 00:05:03
# 10746             42   1  40.070887  116.299294 2008-10-26 00:05:48
# 11571             42   1  40.069563  116.329480 2008-10-26 03:06:38
# 12435             46   1  39.976599  116.387014 2008-10-26 03:45:46
# 13123             46   1  39.976167  116.383538 2008-10-26 06:31:37
# 13124             47   1  39.975894  116.383520 2008-10-26 06:31:39
# 13833             47   1  39.977943  116.327093 2008-10-26 07:07:08
# 13842             50   1  39.977223  116.327262 2008-10-26 08:13:42
# 14235             50   1  39.998400  116.331349 2008-10-26 08:34:21
# 14236             51   1  39.998668  116.331412 2008-10-26 08:34:23
# 15689             51   1  40.013795  116.306502 2008-10-26 22:21:56
# 15693             54   1  40.013992  116.306535 2008-10-26 23:47:03
# 16150             54   1  40.002462  116.321671 2008-10-27 00:17:01
# ...              ...  ..        ...         ...                 ...
# 202335          4491   5  39.976594  116.336374 2009-01-16 14:09:03
# 202706          4491   5  39.974789  116.335120 2009-01-16 14:35:32
# 203620          4518   5  39.979956  116.340811 2009-01-16 15:25:19
# 203919          4518   5  39.976657  116.337568 2009-01-16 15:41:28
# 204597          4555   5  39.976091  116.336037 2009-01-16 18:19:11
# 206020          4555   5  39.976176  116.335944 2009-01-16 21:07:59
# 206021          4556   5  39.975994  116.335244 2009-01-16 21:08:26
# 206800          4556   5  39.977020  116.337718 2009-01-16 22:59:42
# 206801          4557   5  39.976807  116.337338 2009-01-16 22:59:44
# 207261          4557   5  39.975975  116.335851 2009-01-16 23:54:19
# 207721          4580   5  39.908299  116.590504 2009-01-17 08:51:28
# 209008          4580   5  39.903551  116.419657 2009-01-17 09:28:03
# 209009          4581   5  39.994270  116.326845 2009-01-17 10:33:47
# 209149          4581   5  39.995309  116.328426 2009-01-17 10:52:12
# 209156          4583   5  40.000044  116.326984 2009-01-19 10:15:53
# 209484          4583   5  40.009667  116.320185 2009-01-19 11:18:49
# 209570          4586   5  40.009433  116.322764 2009-01-19 12:59:38
# 210986          4586   5  39.999945  116.327439 2009-01-19 14:08:11
# 211541          4600   5  41.112310  121.151275 2009-01-22 01:01:12
# 212029          4600   5  41.118783  121.120368 2009-01-22 01:16:55
# 213952          4644   5  40.009650  116.323211 2009-02-22 05:53:10
# 214099          4644   5  40.003550  116.322399 2009-02-22 07:16:20
# 215172          4679   5  40.000630  116.321953 2009-02-22 11:27:58
# 215408          4679   5  40.010478  116.321621 2009-02-22 11:46:48
# 215984          4702   5  40.002918  116.321179 2009-02-27 15:25:04
# 216201          4702   5  40.008930  116.316370 2009-02-27 15:43:04
# 216653          4761   5  40.003937  116.322378 2009-03-12 09:31:37
# 216715          4761   5  40.009467  116.320154 2009-03-12 09:52:07
# 217072          4781   5  40.008938  116.322648 2009-03-14 05:32:32
# 217314          4781   5  39.990805  116.327712 2009-03-14 06:36:02
#
#         dist_to_prev  dist_to_next  dist_prev_to_next situation  tid_dist  \
# 562              NaN     11.013568          26.512002      move         1
# 1368       16.068387     40.942759          56.717519      move         1
# 1575             NaN     14.366909          50.322414      move         1
# 1847       21.870376     51.683385          53.596809      move         1
# 1938             NaN     20.642805          58.753841      move         1
# 2646        6.437367     73.921445          72.942149      move         1
# 2667             NaN     19.612423          51.388287      move         1
# 3039        5.697464     78.265156          83.404371      move         1
# 3089             NaN      7.587244        4358.356247      move         2
# 3924       12.807471    320.654991         327.200429      move         2
# 4035             NaN     10.710494          48.213454      move         2
# 8376        6.473607     31.094420          37.263285      move         2
# 8377             NaN      8.191995          29.368238      move         2
# 9082        0.278711     66.635675          66.824979      stop         2
# 9258             NaN      9.581952        1887.327005      move         2
# 10168       5.917334    404.619469         404.277322      move         2
# 10172            NaN     20.556597          17.475348      move         2
# 10745      14.683896    832.837119         844.069232      move         2
# 10746            NaN     22.262448         853.339816      move         2
# 11571      21.312961     31.991527          53.142842      move         2
# 12435            NaN      4.280041        4535.822332      move         3
# 13123      10.732034     30.394938          41.115868      move         3
# 13124            NaN     12.151763          42.264467      move         3
# 13833       0.340831     33.430933          33.694844      stop         3
# 13842            NaN      9.304585         373.345687      move         3
# 14235      18.801400     30.279586          48.825762      move         3
# 14236            NaN     22.957358          52.661448      move         3
# 15689       1.811438     78.491406          80.250827      stop         3
# 15693            NaN     16.790650          24.997219      move         3
# 16150       9.150153     54.380990          63.512925      move         3
# ...              ...           ...                ...       ...       ...
# 202335           NaN      6.411604          57.633581      move        16
# 202706      2.638475    112.687245         111.267406      move        16
# 203620           NaN     12.659169         126.204381      move        16
# 203919      1.905241    725.950377         724.385332      stop        16
# 204597           NaN     14.584941         633.975490      move        16
# 206020      5.180888     62.986720          63.157675      move        16
# 206021           NaN      0.717040          62.414116      move        16
# 206800      5.480050     40.117135          34.637103      move        16
# 206801           NaN     15.973148          56.088907      move        16
# 207261      5.583204     72.044710          68.465215      move        16
# 207721           NaN     21.518733       20985.599732      move        17
# 209008      6.296828  12819.978690       12825.985712      move        17
# 209009           NaN      5.641112       12818.445704      move        18
# 209149      2.933556     47.286575          48.871189      move        18
# 209156           NaN     13.127912         462.740492      move        18
# 209484     14.650605     43.250854          31.859196      move        18
# 209570           NaN      7.549854          38.853750      move        18
# 210986      2.734828    188.595658         186.157032      move        18
# 211541           NaN      5.780594          45.316805      move        19
# 212029      2.859299     61.815163          60.241497      move        19
# 213952           NaN     26.477908          59.156210      move        20
# 214099     24.598991     33.481489          57.566291      move        20
# 215172           NaN     16.210203        1062.981283      move        20
# 215408      7.790798    453.726888         460.352157      move        20
# 215984           NaN     25.053212          23.671225      move        20
# 216201      1.223751    520.627318         521.086232      stop        20
# 216653           NaN      6.449310         755.567765      move        20
# 216715      7.443679     32.663739          38.723962      move        20
# 217072           NaN     14.709253          73.928901      move        20
# 217314     14.694606     35.526076          49.736319      move        20
#
#         time_to_prev  speed_to_prev  stop   lat_mean    lon_mean
# 562              NaN            NaN  True  40.013824  116.306535
# 1368             2.0       8.034193  True  40.013824  116.306535
# 1575             NaN            NaN  True  39.980124  116.310749
# 1847          1508.0       0.014503  True  39.980124  116.310749
# 1938             NaN            NaN  True  39.979594  116.313750
# 2646             5.0       1.287473  True  39.979594  116.313750
# 2667             NaN            NaN  True  39.981541  116.310107
# 3039             5.0       1.139493  True  39.981541  116.310107
# 3089             NaN            NaN  True  39.996381  116.299268
# 3924             2.0       6.403736  True  39.996381  116.299268
# 4035             NaN            NaN  True  40.000154  116.165938
# 8376             5.0       1.294721  True  40.000154  116.165938
# 8377             NaN            NaN  True  39.992475  116.204994
# 9082             2.0       0.139355  True  39.992475  116.204994
# 9258             NaN            NaN  True  39.996362  116.286608
# 10168            3.0       1.972445  True  39.996362  116.286608
# 10172            NaN            NaN  True  40.031189  116.313866
# 10745            1.0      14.683896  True  40.031189  116.313866
# 10746            NaN            NaN  True  40.069755  116.331024
# 11571            1.0      21.312961  True  40.069755  116.331024
# 12435            NaN            NaN  True  39.977652  116.384150
# 13123            2.0       5.366017  True  39.977652  116.384150
# 13124            NaN            NaN  True  39.975650  116.385649
# 13833            2.0       0.170416  True  39.975650  116.385649
# 13842            NaN            NaN  True  39.975372  116.333898
# 14235            1.0      18.801400  True  39.975372  116.333898
# 14236            NaN            NaN  True  40.013805  116.306497
# 15689        39525.0       0.000046  True  40.013805  116.306497
# 15693            NaN            NaN  True  40.014950  116.311317
# 16150            5.0       1.830031  True  40.014950  116.311317
# ...              ...            ...   ...        ...         ...
# 202335           NaN            NaN  True  39.975697  116.336035
# 202706           5.0       0.527695  True  39.975697  116.336035
# 203620           NaN            NaN  True  39.977667  116.338788
# 203919           5.0       0.381048  True  39.977667  116.338788
# 204597           NaN            NaN  True  39.976178  116.336199
# 206020           2.0       2.590444  True  39.976178  116.336199
# 206021           NaN            NaN  True  39.976033  116.336186
# 206800           2.0       2.740025  True  39.976033  116.336186
# 206801           NaN            NaN  True  39.976201  116.336258
# 207261           3.0       1.861068  True  39.976201  116.336258
# 207721           NaN            NaN  True  39.906999  116.457662
# 209008           3.0       2.098943  True  39.906999  116.457662
# 209009           NaN            NaN  True  39.995065  116.326601
# 209149           5.0       0.586711  True  39.995065  116.326601
# 209156           NaN            NaN  True  40.009451  116.320408
# 209484           1.0      14.650605  True  40.009451  116.320408
# 209570           NaN            NaN  True  40.009390  116.322575
# 210986           5.0       0.546966  True  40.009390  116.322575
# 211541           NaN            NaN  True  41.113731  121.141849
# 212029           5.0       0.571860  True  41.113731  121.141849
# 213952           NaN            NaN  True  40.005382  116.322092
# 214099           5.0       4.919798  True  40.005382  116.322092
# 215172           NaN            NaN  True  40.010956  116.321853
# 215408           5.0       1.558160  True  40.010956  116.321853
# 215984           NaN            NaN  True  40.008942  116.316356
# 216201           5.0       0.244750  True  40.008942  116.316356
# 216653           NaN            NaN  True  40.009501  116.320438
# 216715           5.0       1.488736  True  40.009501  116.320438
# 217072           NaN            NaN  True  40.004262  116.324129
# 217314           5.0       2.938921  True  40.004262  116.324129
#
# [570 rows x 15 columns]
