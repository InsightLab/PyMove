# %% [markdown]
# # #00 - What is PyMove?
#
# **PyMove** is a Python library, open-source, that have operations to handling trajectories data, ranging from data representation, preprocessing operations, models, and visualization techniques.
#
# PyMove **proposes**:
# - A familiar and similar syntax to Pandas;
# - Clear documentation;
# - Extensibility, since you can implement your main data structure by manipulating other data structures such as Dask DataFrame, numpy arrays, etc., in addition to adding new modules;
# - Flexibility, as the user can switch between different data structures;
# - Operations for data preprocessing, pattern mining and data visualization.
#
# ---
#
# ### Enviroment settings
#
# 1. Make a enviroment using **Conda**
#
# `conda create -n validacao-pymove`
#
# 2. Activate the enviroment
#
# `conda activate validacao-pymove`
#
# #### Using PyMove
# 1. Clone this repository
#
# `git clone https://github.com/InsightLab/PyMove`
#
# 2. Make a branch developer
#
# `git branch developer`
#
# 3. Switch to a new branch
#
# `git checkout developer`
#
# 4. Make a pull of branch
#
# `git pull origin developer`
#
# 5. Switch to folder PyMove
#
# `cd PyMove`
#
# 6. Install in developer mode
#
# `pip install -e .`
#
#
# 7. Now, use this command to use PyMove!
#
# `import pymove`
#
# <!-- ---
#
# ### Estruturas de dados
#
# > Falar sobre as características de estendibilidade
# - Usa Pandas atualmente e está trabalhando para extensão com o Dask
#
# > Falar sobre a esturtura de dados do PyMove
# - MoveDataFrame
# > E se eu quiser trabalhar com outra camada abaixo da estrutura?
# - Falar que deve implementar os métodos da interface.py
#  -->
# ---
#
# ### What can you do with PyMove?
#
# With Pymove you can handling trajectories data with operations of:
# <!-- - Nova estrutura de dados que permite permutar sobre diferentes bibliotecas de manipular dados
# - Grid -->
# - Preprocessing: this including segmentation, compression, noise filter, stay point detection and map matching techniques.
# - Data Visualization: exploring differents techniques and channels to view your data!
#
# ---
#
# ### Material de consulta
# * [Notebooks Pymove](https://github.com/InsightLab/PyMove/tree/developer/examples)
