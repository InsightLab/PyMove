# %% [markdown]
# # 06 - Exploring Integrations

# %% [markdown]
# ## 0. Required library installations

# %% [markdown]
# For the execution of one of the integration functions that will be presented here, the geopandas library needs to be installed. To obtain some data for demonstrating the functions, the omnsx library also needs to be installed

# %% [markdown]
# ```
# conda install geopandas osmnx
# ```

# %% [markdown]
# ## 1. Imports

# %%
import pymove as pm
from pymove.utils import integration as it
from pymove.visualization import folium
import numpy as np
import pandas as pd
import geopandas

# %% [markdown]
# ## 2. Load Data

# %%
move_df = pm.read_csv('geolife_sample.csv', nrows=5000)
move_df.head()
# Out:
#          lat         lon            datetime  id
# 0  39.984094  116.319236 2008-10-23 05:53:05   1
# 1  39.984198  116.319322 2008-10-23 05:53:06   1
# 2  39.984224  116.319402 2008-10-23 05:53:11   1
# 3  39.984211  116.319389 2008-10-23 05:53:16   1
# 4  39.984217  116.319422 2008-10-23 05:53:21   1

# %%
#Tamanho
move_df.shape[0]
# Out:
# 5000

# %% [markdown]
# ### Visualization

# %%
folium.plot_trajectories_with_folium(move_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6d7a25854a4e4ea48f1226b1dca15aa0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6d7a25854a4e4ea48f1226b1dca15aa0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%3C%21doctype%20html%3E%0A%20%20%20%20%3Chtml%20lang%3D%22en%22%3E%0A%20%20%20%20%3Chead%3E%0A%20%20%20%20%20%20%3Cmeta%20charset ...

# %% [markdown]
# ## 3. Loading points of interest

# %%
bbox = move_df.get_bbox()
folium.plot_bbox(bbox, color='blue')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ac36fd84cc754343ababab8965f0193f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ac36fd84cc754343ababab8965f0193f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ac36fd84cc754343ababab8965f0193f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ac36fd84cc754343ababab8965f0193f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
import osmnx as ox

tags = {'amenity':True}
POIs = ox.geometries_from_bbox(north=bbox[0], south=bbox[2], east=bbox[3], west=bbox[1], tags=tags)

# %%
POIs.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         unique_id      osmid element_type    amenity  fee  \
# 0  node/269492188  269492188         node    toilets   no
# 1  node/274942287  274942287         node    toilets  NaN
# 2  node/276320137  276320137         node  fast_food  NaN
# 3  node/276320142  276320142         node    massage  NaN
# 4  node/286242547  286242547         node    toilets  NaN
#
#                      geometry  cuisine            name name:en  atm  ...  \
# 0  POINT (116.26750 39.98087)      NaN             NaN     NaN  NaN  ...
# 1  POINT (116.27358 39.99664)      NaN             NaN     NaN  NaN  ...
# 2  POINT (116.33756 39.97541)  chinese            永和大王     NaN  NaN  ...
# 3  POINT (116.33751 39.97546)      NaN  Footmassage 富橋     NaN  NaN  ...
# 4  POINT (116.19982 40.00670)      NaN             NaN     NaN  NaN  ...
#
#   building:material roof:colour roof:material alt_name_1 not:name area ways  \
# 0               NaN         NaN           NaN        NaN      NaN  NaN  NaN
# 1               NaN         NaN           NaN        NaN      NaN  NaN  NaN
# 2               NaN         NaN           NaN        NaN      NaN  NaN  NaN
# 3               NaN         NaN           NaN        NaN      NaN  NaN  NaN
# 4               NaN         NaN           NaN        NaN      NaN  NaN  NaN
#
#   type name:ja name:ko
# 0  NaN     NaN     NaN
# 1  NaN     NaN     NaN
# 2  NaN     NaN     NaN
# 3  NaN     NaN     NaN
# 4  NaN     NaN     NaN
#
# [5 rows x 118 columns]

# %% [markdown]
# Removing unrated (null) points of interest

# %%
POIs = POIs.dropna(subset=["amenity"], inplace=False)
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Adapting to the format needed for integration (With labels 'lat' and 'lon' referring to latitude and longitude, respectively)

# %%
POIs = POIs[POIs['geometry'].type == 'Point']
POIs['lon'] = POIs['geometry'].x
POIs['lat'] = POIs['geometry'].y
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Visualization

# %%
m = folium.plot_trajectories_with_folium(move_df)
folium.plot_poi_folium(POIs, slice_tags=['amenity'], base_map=m, poi_point='blue')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d3777c3e2f124360b510a2a34128f3e6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d3777c3e2f124360b510a2a34128f3e6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%3C%21doctype%20html%3E%0A%20%20%20%20%3Chtml%20lang%3D%22en%22%3E%0A%20%20%20%20%3Chead%3E%0A%20%20%20%20%20%20%3Cmeta%20charset ...

# %% [markdown]
# ## 4. Integrating Points of Interest into the DataSet

# %%
df_4 = move_df.copy()
it.join_with_pois(df_4, POIs, label_id='osmid', label_poi_name='name')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %% [markdown]
# Result

# %%
df_4.head()
# Out:
#          lat         lon            datetime  id      id_poi    dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  5572452688  116.862844
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  5572452688  119.142692
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  5572452688  116.595117
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  5572452688  116.257378
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  5572452688  114.886759
#
#       name_poi
# 0  太平洋影城(中关村店)
# 1  太平洋影城(中关村店)
# 2  太平洋影城(中关村店)
# 3  太平洋影城(中关村店)
# 4  太平洋影城(中关村店)

# %% [markdown]
# Point of interest closest to each point of the trajectory

# %%
df_4['name_poi'].unique()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['太平洋影城(中关村店)', '东亚银行', '南京银行', '星巴克', '小吊梨汤', nan, '鑫蜀源', '必胜客',
#        '潜渊', '上岛咖啡', '科苑餐厅', '2nd Place', '元绿回转寿司', '中信银行', 'HSBC', '咖啡王',
#        '招商银行', '中国建设银行', 'Paradiso Coffee', '798 bar', 'Jazz Cafe',
#        'Hundred Years Cafe', '安家小厨', '清青快餐', '听涛园', '仰望咖啡',
#        'China Construction Bank', '同仁堂', '北园餐厅', '北京银行', '交通银行', '宁波银行',
#        '美嘉欢乐影城', '北京101中学', '西苑医院', 'Yu Xiao Mian Noodles', '茶大爷',
#        "McDonald's", 'Pizza Hut', 'Starbucks', '云海肴', '兰州老妈拉面',
#        'Пекинский Ботанический сад (Парковка) 植物园停车场'], dtype=object)

# %% [markdown]
# ## 5. Integrating Points of Interest into the DataSet (Using join_with_pois_optimizer)

# %% [markdown]
# Selecting data

# %%
POIs_5 = POIs[0:10].copy()
POIs_5['type_poi'] = POIs_5['amenity']
df_5 = move_df.copy()

# %%
POIs_5['type_poi'].unique()
# Out:
# array(['toilets', 'fast_food', 'massage', 'waste_basket', 'parking',
#        'cafe', 'restaurant', 'bank'], dtype=object)

# %% [markdown]
# Executing the function

# %%
it.join_with_pois_optimizer(df_5, POIs_5, label_id='osmid', label_poi_name='name', dist_poi=np.array([100,9,1,50,50,10,20]))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=10)))
# <__array_function__ internals>:5: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.

# %%
df_5.head()
# Out:
#          lat         lon            datetime  id     id_poi     dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  269492188  1144.603484
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  269492188  1131.338544
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  269492188  1124.395459
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  269492188  1126.193301
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  269492188  1123.692580
#
#   name_poi
# 0  toilets
# 1  toilets
# 2  toilets
# 3  toilets
# 4  toilets

# %% [markdown]
# ## 6. Integrating Points of Interest into the Category-Based DataSet

# %%
df_6 = move_df.copy()
it.join_with_pois_by_category(df_6, POIs_5, label_category='amenity', label_id='id')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
df_6.head(10)
# Out:
#          lat         lon            datetime  id id_toilets  dist_toilets  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  274942287   4132.229067
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  274942287   4135.240296
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  274942287   4140.698090
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  274942287   4140.136625
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  274942287   4142.564150
# 5  39.984710  116.319865 2008-10-23 05:53:23   1  274942287   4160.348133
# 6  39.984674  116.319810 2008-10-23 05:53:28   1  274942287   4157.187813
# 7  39.984623  116.319773 2008-10-23 05:53:33   1  274942287   4156.022778
# 8  39.984606  116.319732 2008-10-23 05:53:38   1  274942287   4153.324576
# 9  39.984555  116.319728 2008-10-23 05:53:43   1  274942287   4154.833968
#
#   id_fast_food  dist_fast_food id_massage  dist_massage id_waste_basket  \
# 0    276320137     1835.502157  276320142   1829.070918       286246121
# 1    276320137     1835.403414  276320142   1828.951254       286246121
# 2    276320137     1831.182086  276320142   1824.720741       286246121
# 3    276320137     1831.345213  276320142   1824.886604       286246121
# 4    276320137     1829.326076  276320142   1822.864349       286246121
# 5    276320137     1827.992513  276320142   1821.434719       286246121
# 6    276320137     1829.602658  276320142   1823.053098       286246121
# 7    276320137     1829.027475  276320142   1822.486938       286246121
# 8    276320137     1830.866492  276320142   1824.330899       286246121
# 9    276320137     1827.989263  276320142   1821.460600       286246121
#
#    dist_waste_basket id_parking  dist_parking    id_cafe    dist_cafe  \
# 0       10028.323311  286251975   9867.997250  290600874  1144.603484
# 1       10033.797904  286251975   9874.072277  290600874  1131.338544
# 2       10040.095434  286251975   9880.550663  290600874  1124.395459
# 3       10039.220172  286251975   9879.599237  290600874  1126.193301
# 4       10041.897836  286251975   9882.326278  290600874  1123.692580
# 5       10071.059512  286251975   9914.343371  290600874  1058.680139
# 6       10067.008973  286251975   9910.073317  290600874  1064.838599
# 7       10064.722571  286251975   9907.496404  290600874  1071.002908
# 8       10061.545473  286251975   9904.207906  290600874  1074.850689
# 9       10062.044871  286251975   9904.433434  290600874  1078.957681
#
#   id_restaurant  dist_restaurant    id_bank    dist_bank
# 0     297407376      2003.585998  297407444  1883.831094
# 1     297407376      2002.819358  297407444  1883.466601
# 2     297407376      1998.303264  297407444  1879.127020
# 3     297407376      1998.555890  297407444  1879.325712
# 4     297407376      1996.436934  297407444  1877.266370
# 5     297407376      1991.704195  297407444  1874.593280
# 6     297407376      1993.624392  297407444  1876.325343
# 7     297407376      1993.387313  297407444  1875.882508
# 8     297407376      1995.406736  297407444  1877.792905
# 9     297407376      1992.786980  297407444  1875.015873

# %% [markdown]
# ## 7. Integrating events (points of interest with timestamp) to the DataSet

# %% [markdown]
# It integrates a normal dataframe with Points of interest of events, that is, in addition to the labels referring to latitude and longitude, it also has a label referring to the datetime in which the event occurred. In this example, we will assign random date and time values to some POIs to simulate an operation.

# %%
indexOfPois = np.arange(0, POIs.shape[0], POIs.shape[0]/20, dtype=np.int64)
POIs_events = POIs.iloc[indexOfPois].copy()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
randomIndexOfMoveDf = np.arange(0, move_df.shape[0], move_df.shape[0]/20, dtype=np.int64)
randomMoveDfSlice = move_df.iloc[randomIndexOfMoveDf].copy()

# %%
POIs_events['datetime'] = randomMoveDfSlice['datetime'].copy()

# %%
df_7 = move_df.copy()

# %%
it.join_with_poi_datetime(
    df_7, POIs_events, 
    label_date='datetime', time_window=900, 
    label_event_id='osmid', label_event_type='amenity'
)
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
df_7.head()
# Out:
#          lat         lon            datetime  id      osmid   dist_event  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  269492188  4422.237186
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  269492188  4430.488277
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  269492188  4437.521909
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  269492188  4436.297310
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  269492188  4439.154806
#
#    amenity
# 0  toilets
# 1  toilets
# 2  toilets
# 3  toilets
# 4  toilets

# %% [markdown]
# ## 8. Optimized Integrating events (points of interest with timestamp) to the DataSet

# %%
df_8 = move_df.copy()
POIs_events["event_id"] = POIs_events["osmid"]
POIs_events["event_type"] = POIs_events["amenity"]
it.join_with_poi_datetime_optimizer(df_8, POIs_events)
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# <__array_function__ internals>:5: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.

# %%
df_8.head()
# Out:
#          lat         lon            datetime  id   event_id  dist_event  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1  269492188  118.990536
# 1  39.984198  116.319322 2008-10-23 05:53:06   1  269492188  120.895985
# 2  39.984224  116.319402 2008-10-23 05:53:11   1  269492188  118.147609
# 3  39.984211  116.319389 2008-10-23 05:53:16   1  269492188  117.863168
# 4  39.984217  116.319422 2008-10-23 05:53:21   1  269492188  116.416939
#
#   event_type
# 0    toilets
# 1    toilets
# 2    toilets
# 3    toilets
# 4    toilets

# %% [markdown]
# ## 9. Integration with Point of Interest HOME

# %% [markdown]
# The Home type contains, in addition to latitude, longitude and id, the address and city labels.

# %% [markdown]
# Creating a home point

# %%
df_9 = move_df.copy()
home_df = df_9.iloc[300:302].copy()
home_df['formatted_address'] = ['Rua1, n02', 'Rua2, n03']
home_df['city'] = ['ChinaTown', 'ChinaTown']
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Using the function

# %%
it.join_with_home_by_id(df_9, home_df, label_id='id')
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1)))

# %%
df_9.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    id        lat         lon            datetime    dist_home       home  \
# 0   1  39.984094  116.319236 2008-10-23 05:53:05  1031.348370  Rua1, n02
# 1   1  39.984198  116.319322 2008-10-23 05:53:06  1017.690147  Rua1, n02
# 2   1  39.984224  116.319402 2008-10-23 05:53:11  1011.332141  Rua1, n02
# 3   1  39.984211  116.319389 2008-10-23 05:53:16  1013.152700  Rua1, n02
# 4   1  39.984217  116.319422 2008-10-23 05:53:21  1010.959220  Rua1, n02
#
#         city
# 0  ChinaTown
# 1  ChinaTown
# 2  ChinaTown
# 3  ChinaTown
# 4  ChinaTown

# %% [markdown]
# ## 10. Merge of HOME with DataSet already integrated with POIs

# %% [markdown]
# Integration

# %%
it.join_with_pois(df_9, POIs, label_id='osmid', label_poi_name='name')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
it.merge_home_with_poi(df_9)

# %%
df_9.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    id        lat         lon            datetime       city      id_poi  \
# 0   1  39.984094  116.319236 2008-10-23 05:53:05  ChinaTown  5572452688
# 1   1  39.984198  116.319322 2008-10-23 05:53:06  ChinaTown  5572452688
# 2   1  39.984224  116.319402 2008-10-23 05:53:11  ChinaTown  5572452688
# 3   1  39.984211  116.319389 2008-10-23 05:53:16  ChinaTown  5572452688
# 4   1  39.984217  116.319422 2008-10-23 05:53:21  ChinaTown  5572452688
#
#      dist_poi     name_poi
# 0  116.862844  太平洋影城(中关村店)
# 1  119.142692  太平洋影城(中关村店)
# 2  116.595117  太平洋影城(中关村店)
# 3  116.257378  太平洋影城(中关村店)
# 4  114.886759  太平洋影城(中关村店)

# %% [markdown]
# ## 11. Union functions

# %% [markdown]
# They have the purpose of joining several types of POI that mean the same thing, or similar things, in a single type of POI

# %% [markdown]
# ### Union of Banks

# %% [markdown]
# Converts POIs of the types "bank_filials", "bank_agencies", "bank_posts", "bank_PAE" and "bank" to a single type: "banks"

# %%
df_banks = move_df.copy()

#We create POIs with different type_poi that describe different types of banks to test
indexes_bp = np.linspace(0, df_banks.shape[0], 6)
banks_pois = df_banks[df_banks.index.isin(indexes_bp)].copy()
banks_pois['id'] = [0,1,2,3,4]
banks_pois['type_poi'] = ['bancos_filiais', 'bancos_agencias', 'bancos_postos', 'bancos_PAE', 'bank']

banks_pois.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             lat         lon            datetime  id         type_poi
# 0     39.984094  116.319236 2008-10-23 05:53:05   0   bancos_filiais
# 1000  40.014125  116.306159 2008-10-23 23:43:56   1  bancos_agencias
# 2000  39.979558  116.312653 2008-10-24 03:26:10   2    bancos_postos
# 3000  39.979370  116.320649 2008-10-24 06:31:04   3       bancos_PAE
# 4000  40.003274  116.267484 2008-10-25 00:54:34   4             bank

# %%
#Join with POIs
it.join_with_pois(df_banks, banks_pois, label_id='id', label_poi_name='type_poi')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
#Result
df_banks.head(10)
# Out:
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      0   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      0  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      0  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      0  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      0  20.933073
# 5  39.984710  116.319865 2008-10-23 05:53:23   1      0  86.969343
# 6  39.984674  116.319810 2008-10-23 05:53:28   1      0  80.938365
# 7  39.984623  116.319773 2008-10-23 05:53:33   1      0  74.520547
# 8  39.984606  116.319732 2008-10-23 05:53:38   1      0  70.901768
# 9  39.984555  116.319728 2008-10-23 05:53:43   1      0  66.217975
#
#          name_poi
# 0  bancos_filiais
# 1  bancos_filiais
# 2  bancos_filiais
# 3  bancos_filiais
# 4  bancos_filiais
# 5  bancos_filiais
# 6  bancos_filiais
# 7  bancos_filiais
# 8  bancos_filiais
# 9  bancos_filiais

# %%
#Checking the amount of each point assigned to each type of poi
bancos_filiais = df_banks.loc[df_banks['name_poi'] == 'bancos_filiais']
bancos_agencias = df_banks.loc[df_banks['name_poi'] == 'bancos_agencias']
bancos_postos = df_banks.loc[df_banks['name_poi'] == 'bancos_postos']
bancos_PAE = df_banks.loc[df_banks['name_poi'] == 'bancos_PA']
bank = df_banks.loc[df_banks['name_poi'] == 'bank']

print("Number of points close to each bank definition")
print("bancos_filiais: ", bancos_filiais.shape[0])
print("bancos_agencias: ", bancos_agencias.shape[0])
print("bancos_postos: ", bancos_postos.shape[0])
print("bancos_PAE: ", bancos_PAE.shape[0])
print("bank: ", bank.shape[0])
# Out:
# Number of points close to each bank definition
# bancos_filiais:  579
# bancos_agencias:  1407
# bancos_postos:  916
# bancos_PAE:  0
# bank:  1238
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Finally, the Union
it.union_poi_bank(df_banks, label_poi="name_poi")

#Result
df_banks.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi name_poi
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      0   0.000000    banks
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      0  13.690153    banks
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      0  20.223428    banks
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      0  18.416895    banks
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      0  20.933073    banks

# %%
#Checking
df_banks.loc[df_banks['name_poi'] == 'banks'].shape[0]
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5000

# %% [markdown]
# ### Union of Bus Stations

# %% [markdown]
# Converts "transit_station" and "bus_points" POIs to a single type: "bus_station"

# %%
df_bus = move_df.copy()


#We create POIs with different name_poi that describe different types of bus stops to test
indexes_bp = np.linspace(0, df_bus.shape[0], 6)
bus_pois = df_bus[df_bus.index.isin(indexes_bp)].copy()
bus_pois['id'] = [0,1,2,3,4]
bus_pois['name_poi'] = ['transit_station', 'transit_station', 'pontos_de_onibus', 'transit_station', 'pontos_de_onibus']

#Result
bus_pois.head()
# Out:
#             lat         lon            datetime  id          name_poi
# 0     39.984094  116.319236 2008-10-23 05:53:05   0   transit_station
# 1000  40.014125  116.306159 2008-10-23 23:43:56   1   transit_station
# 2000  39.979558  116.312653 2008-10-24 03:26:10   2  pontos_de_onibus
# 3000  39.979370  116.320649 2008-10-24 06:31:04   3   transit_station
# 4000  40.003274  116.267484 2008-10-25 00:54:34   4  pontos_de_onibus

# %%
#Integration
it.join_with_pois(df_bus, bus_pois, label_id='id', label_poi_name='name_poi')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
#Result
df_bus.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      0   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      0  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      0  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      0  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      0  20.933073
#
#           name_poi
# 0  transit_station
# 1  transit_station
# 2  transit_station
# 3  transit_station
# 4  transit_station

# %%
transit_station = df_bus.loc[df_bus['name_poi'] == 'transit_station']
pontos_de_onibus = df_bus.loc[df_bus['name_poi'] == 'pontos_de_onibus']

print("Number of points near transit_station's: ", transit_station.shape[0])
print("Number of points close to pontos_de_onibus's: ", pontos_de_onibus.shape[0])
# Out:
# Number of points near transit_station's:  2846
# Number of points close to pontos_de_onibus's:  2154
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#The union function
it.union_poi_bus_station(df_bus, label_poi="name_poi")

df_bus.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      0   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      0  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      0  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      0  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      0  20.933073
#
#       name_poi
# 0  bus_station
# 1  bus_station
# 2  bus_station
# 3  bus_station
# 4  bus_station

# %%
#Checking

df_bus.loc[df_bus['name_poi'] == 'bus_station'].shape[0]
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5000

# %% [markdown]
# ### Union of Bars and Restaurants

# %% [markdown]
# Converts "bar" and "restaurant" POIs to a single type: "bar-restaurant"

# %%
df_bar = move_df.copy()

#We create POIs with both types
indexes_br = np.linspace(0, df_bar.shape[0], 5)
br_POIs = df_bar[df_bar.index.isin(indexes_br)].copy()
br_POIs['name_poi'] = ['bar','restaurant','restaurant', 'bar']

#Result
br_POIs.head()
# Out:
#             lat         lon            datetime  id    name_poi
# 0     39.984094  116.319236 2008-10-23 05:53:05   1         bar
# 1250  39.999756  116.322556 2008-10-23 23:58:02   1  restaurant
# 2500  39.979533  116.323162 2008-10-24 05:31:19   1  restaurant
# 3750  39.996251  116.293837 2008-10-25 00:40:56   1         bar

# %%
#Integration
it.join_with_pois(df_bar, br_POIs, label_id='id', label_poi_name='name_poi')
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))

# %%
#Result
df_bar.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi name_poi
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000      bar
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153      bar
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428      bar
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895      bar
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073      bar

# %%
#Number of points close to each type
bar = df_bar.loc[df_bar['name_poi'] == 'bar']
restaurant = df_bar.loc[df_bar['name_poi'] == 'restaurant']

print("Closest type points 'bar': ", bar.shape[0])
print("Closest type points 'restaurant': ", restaurant.shape[0])
# Out:
# Closest type points 'bar':  2539
# Closest type points 'restaurant':  2461
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Union of the two types of POIs into a single
it.union_poi_bar_restaurant(df_bar, label_poi="name_poi")

#Result
df_bar.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073
#
#          name_poi
# 0  bar-restaurant
# 1  bar-restaurant
# 2  bar-restaurant
# 3  bar-restaurant
# 4  bar-restaurant

# %%
#Checking
df_bar.loc[df_bar['name_poi'] == 'bar-restaurant'].shape[0]
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5000

# %% [markdown]
# ### Union of Parks

# %% [markdown]
# Converts "pracas_e_parques" and "park" POIs to a single type: "parks"

# %%
df_parks = move_df.copy()

#We create POIs with both types
indexes_p = np.linspace(0, df_parks.shape[0], 5)
p_POIs = df_parks[df_parks.index.isin(indexes_p)].copy()
p_POIs['name_poi'] = ['pracas_e_parques','pracas_e_parques','park', 'park']

#Result
p_POIs.head()
# Out:
#             lat         lon            datetime  id          name_poi
# 0     39.984094  116.319236 2008-10-23 05:53:05   1  pracas_e_parques
# 1250  39.999756  116.322556 2008-10-23 23:58:02   1  pracas_e_parques
# 2500  39.979533  116.323162 2008-10-24 05:31:19   1              park
# 3750  39.996251  116.293837 2008-10-25 00:40:56   1              park

# %%
#Integration
it.join_with_pois(df_parks, p_POIs, label_id='id', label_poi_name='name_poi')

#Result
df_parks.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073
#
#            name_poi
# 0  pracas_e_parques
# 1  pracas_e_parques
# 2  pracas_e_parques
# 3  pracas_e_parques
# 4  pracas_e_parques

# %%
#Number of points close to each type of POI
pracas_e_parques = df_parks.loc[df_parks['name_poi'] == 'pracas_e_parques']
park = df_parks.loc[df_parks['name_poi'] == 'park']

print("Number of points closest to pracas_e_parques: ", pracas_e_parques.shape[0])
print("Number of points closest to park: ", park.shape[0])
# Out:
# Number of points closest to pracas_e_parques:  2716
# Number of points closest to park:  2284
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Union function
it.union_poi_parks(df_parks, label_poi="name_poi")

df_parks.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi name_poi
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000    parks
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153    parks
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428    parks
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895    parks
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073    parks

# %%
#Checking the new quantity
df_parks.loc[df_parks['name_poi'] == 'parks'].shape[0]
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5000

# %% [markdown]
# ### Union of police points

# %%
df_police = move_df.copy()

#We create POIs with both types
indexes_pol = np.linspace(0, df_police.shape[0], 5)
pol_POIs = df_police[df_police.index.isin(indexes_pol)].copy()
pol_POIs['name_poi'] = ['distritos_policiais','police','distritos_policiais', 'distritos_policiais']

#Result
pol_POIs.head()
# Out:
#             lat         lon            datetime  id             name_poi
# 0     39.984094  116.319236 2008-10-23 05:53:05   1  distritos_policiais
# 1250  39.999756  116.322556 2008-10-23 23:58:02   1               police
# 2500  39.979533  116.323162 2008-10-24 05:31:19   1  distritos_policiais
# 3750  39.996251  116.293837 2008-10-25 00:40:56   1  distritos_policiais

# %%
#Integration
it.join_with_pois(df_police, pol_POIs, label_id='id', label_poi_name='name_poi')

df_police.head()
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=5000)))
#          lat         lon            datetime  id id_poi   dist_poi  \
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073
#
#               name_poi
# 0  distritos_policiais
# 1  distritos_policiais
# 2  distritos_policiais
# 3  distritos_policiais
# 4  distritos_policiais

# %%
#Quantity of points closest to each type of point
distritos_policiais = df_police.loc[df_police['name_poi'] == 'distritos_policiais']

print("Number of points closest to distritos_policiais: ", distritos_policiais.shape[0])
# Out:
# Number of points closest to distritos_policiais:  3420
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Union funcion
it.union_poi_police(df_police, label_poi="name_poi")

# %%
#Result
df_police.head()
# Out:
#          lat         lon            datetime  id id_poi   dist_poi name_poi
# 0  39.984094  116.319236 2008-10-23 05:53:05   1      1   0.000000   police
# 1  39.984198  116.319322 2008-10-23 05:53:06   1      1  13.690153   police
# 2  39.984224  116.319402 2008-10-23 05:53:11   1      1  20.223428   police
# 3  39.984211  116.319389 2008-10-23 05:53:16   1      1  18.416895   police
# 4  39.984217  116.319422 2008-10-23 05:53:21   1      1  20.933073   police

# %%
#Checking
df_police.loc[df_police['name_poi'] == 'police'].shape[0]
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5000

# %% [markdown]
# ## 12. Integração entre trajetórias e áreas coletivas

# %%
df_pd = pd.read_csv('geolife_sample.csv')
df_12 = df_pd[0:2000]
gdf = geopandas.GeoDataFrame(df_12, geometry=geopandas.points_from_xy(df_12.lon, df_12.lat))
gdf.head()
# Out:
#          lat         lon             datetime  id                    geometry
# 0  39.984094  116.319236  2008-10-23 05:53:05   1  POINT (116.31924 39.98409)
# 1  39.984198  116.319322  2008-10-23 05:53:06   1  POINT (116.31932 39.98420)
# 2  39.984224  116.319402  2008-10-23 05:53:11   1  POINT (116.31940 39.98422)
# 3  39.984211  116.319389  2008-10-23 05:53:16   1  POINT (116.31939 39.98421)
# 4  39.984217  116.319422  2008-10-23 05:53:21   1  POINT (116.31942 39.98422)

# %%
#Creating collective areas
indexes_ac = np.linspace(0, gdf.shape[0], 5)
area_c = df_12[df_12.index.isin(indexes_ac)].copy()
area_c
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             lat         lon             datetime  id  \
# 0     39.984094  116.319236  2008-10-23 05:53:05   1
# 500   40.006436  116.317701  2008-10-23 10:53:31   1
# 1000  40.014125  116.306159  2008-10-23 23:43:56   1
# 1500  39.979009  116.326873  2008-10-24 00:11:29   1
#
#                         geometry
# 0     POINT (116.31924 39.98409)
# 500   POINT (116.31770 40.00644)
# 1000  POINT (116.30616 40.01412)
# 1500  POINT (116.32687 39.97901)

# %%
#Integration
it.join_collective_areas(gdf, area_c)
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# VBox(children=(HTML(value=''), IntProgress(value=0, max=4)))

# %%
gdf.head()
# Out:
#          lat         lon             datetime  id                    geometry  \
# 0  39.984094  116.319236  2008-10-23 05:53:05   1  POINT (116.31924 39.98409)
# 1  39.984198  116.319322  2008-10-23 05:53:06   1  POINT (116.31932 39.98420)
# 2  39.984224  116.319402  2008-10-23 05:53:11   1  POINT (116.31940 39.98422)
# 3  39.984211  116.319389  2008-10-23 05:53:16   1  POINT (116.31939 39.98421)
# 4  39.984217  116.319422  2008-10-23 05:53:21   1  POINT (116.31942 39.98422)
#
#    violating
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# ### Viewing points on the map

# %% [markdown]
# Collective Area points

# %%
folium.plot_markers(area_c)
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1ba8f35741ab4c1fbdd8780c65176ce3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1ba8f35741ab4c1fbdd8780c65176ce3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1ba8f35741ab4c1fbdd8780c65176ce3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1ba8f35741ab4c1fbdd8780c65176ce3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.995265%2C%20116.3184685%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Corresponding points

# %%
folium.plot_markers(gdf.loc[gdf['violating'] == True])
# Out:
# /home/flycher/anaconda3/envs/pmv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_915411e77f524b28ac88141996124c9d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_915411e77f524b28ac88141996124c9d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_915411e77f524b28ac88141996124c9d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_915411e77f524b28ac88141996124c9d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.995265%2C%20116.3184685%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
